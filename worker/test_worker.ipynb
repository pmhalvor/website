# %%
import os 
# %load_ext autoreload
# %autoreload 2

# %%
conn_str = os.environ.get('AZURE_STORAGE')

# %%
from song_history import get_recents
from authorize import get_token

# %%
token = get_token()

# %%
# get_recents(token)

# %%
import song_history as sh

df, last = sh.download_to_df()

# %%
last
# Out:
# '2020-12-15T16:39:59.043Z'

# %%
df.tail()
# Out:
#                      played_at                      id         artist  \
# 8039  2020-12-15T16:23:02.932Z  05kGKBMBFTpccppj8GdTHH     Max Cooper
# 8040  2020-12-15T16:29:29.223Z  0JdLQuNfeTQdJ6X5lu9wMJ  Felipe Gordon
# 8041  2020-12-15T16:34:36.653Z  2RR47Gjs1h1qhcKFUEchWv          DJOKO
# 8042  2020-12-15T16:38:53.423Z  4b6WRfxJRY40RBpl3TMQVq         Bonobo
# 8043  2020-12-15T16:39:59.043Z  2lv5WyqONymgC5k1MN2q2s      Bergmönch
#
#                                  name
# 8039                 Perpetual Motion
# 8040  Definitely and Completely Mayor
# 8041                    Rise Together
# 8042                       Heartbreak
# 8043                              RDU

# %%
df.tail(60)
# Out:
#                      played_at                      id             artist  \
# 7404  2020-11-09T15:07:26.162Z  0lrA8ALsMPm3KLy78SbSGt            FloFilz
# 7405  2020-11-09T15:09:30.463Z  41ixPCCGNs2VBbmuyl0No4            FloFilz
# 7406  2020-12-07T14:02:26.940Z  6kTteVJEEkVs3Zges11EPO      Leon Vynehall
# 7407  2020-12-07T14:06:10.753Z  1OD2YXIOmfYmBAYfV1maRV      Leon Vynehall
# 7408  2020-12-07T14:27:16.710Z  53jeGIP3iM5S1wYILdgVmq      Leon Vynehall
# 7409  2020-12-07T14:35:39.807Z  19uZpCvv7D2xcz2KwXFgiO      Leon Vynehall
# 7410  2020-12-07T14:40:11.200Z  3q5wn2zu1Bt5NOxmwfGtCn  Michael Christmas
# 7411  2020-12-07T14:46:44.840Z  3qAvjZ84KUD5cCWkt4iCcb      Kornél Kovács
# 7412  2020-12-07T14:52:58.667Z  13T8SvWHczyBPzOemKtEe7             Subjoi
# 7413  2020-12-07T15:01:21.852Z  3ilkEyg6OCtd9qCnOJkPzU          DJ BORING
# 7414  2020-12-07T15:07:08.281Z  4sWJCVOn705QUBCDt81bPB             Baltra
# 7415  2020-12-07T15:13:10.796Z  239SrBPZi0xs1OQZmedr6q    Oliver Koletzki
# ...
