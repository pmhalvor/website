# %%
import os 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
conn_str = os.environ.get('AZURE_STORAGE')

# %%
from song_history import get_recents
from authorize import get_token

# %%
token = get_token()

# %%
# get_recents(token)

# %%
import song_history as sh

df, last = sh.load_df()

# %%
last
# Out:
# '2020-12-15T16:39:59.043Z'

# %%
df.tail()
# Out:
#                      played_at                      id         artist  \
# 8039  2020-12-15T16:23:02.932Z  05kGKBMBFTpccppj8GdTHH     Max Cooper
# 8040  2020-12-15T16:29:29.223Z  0JdLQuNfeTQdJ6X5lu9wMJ  Felipe Gordon
# 8041  2020-12-15T16:34:36.653Z  2RR47Gjs1h1qhcKFUEchWv          DJOKO
# 8042  2020-12-15T16:38:53.423Z  4b6WRfxJRY40RBpl3TMQVq         Bonobo
# 8043  2020-12-15T16:39:59.043Z  2lv5WyqONymgC5k1MN2q2s      Bergmönch
#
#                                  name
# 8039                 Perpetual Motion
# 8040  Definitely and Completely Mayor
# 8041                    Rise Together
# 8042                       Heartbreak
# 8043                              RDU

# %%
df.tail(60)
# Out:
#                      played_at                      id             artist  \
# 7404  2020-11-09T15:07:26.162Z  0lrA8ALsMPm3KLy78SbSGt            FloFilz
# 7405  2020-11-09T15:09:30.463Z  41ixPCCGNs2VBbmuyl0No4            FloFilz
# 7406  2020-12-07T14:02:26.940Z  6kTteVJEEkVs3Zges11EPO      Leon Vynehall
# 7407  2020-12-07T14:06:10.753Z  1OD2YXIOmfYmBAYfV1maRV      Leon Vynehall
# 7408  2020-12-07T14:27:16.710Z  53jeGIP3iM5S1wYILdgVmq      Leon Vynehall
# 7409  2020-12-07T14:35:39.807Z  19uZpCvv7D2xcz2KwXFgiO      Leon Vynehall
# 7410  2020-12-07T14:40:11.200Z  3q5wn2zu1Bt5NOxmwfGtCn  Michael Christmas
# 7411  2020-12-07T14:46:44.840Z  3qAvjZ84KUD5cCWkt4iCcb      Kornél Kovács
# 7412  2020-12-07T14:52:58.667Z  13T8SvWHczyBPzOemKtEe7             Subjoi
# 7413  2020-12-07T15:01:21.852Z  3ilkEyg6OCtd9qCnOJkPzU          DJ BORING
# 7414  2020-12-07T15:07:08.281Z  4sWJCVOn705QUBCDt81bPB             Baltra
# 7415  2020-12-07T15:13:10.796Z  239SrBPZi0xs1OQZmedr6q    Oliver Koletzki
# ...

# %%
import requests as r

# %%
token
# Out:
# 'BQDi6jYjZKIqN9nPXSWoa0UEpcKBemvHphNChAvv_BhySk5Q_1fARiHjHxrWYCN7FybW6z_oHUh1voOzEaaREcUgtYvUAAmU_diskoyMKb_warljGZ3QjaMkbXZAv31uRzTXeB66BvWS2NbhXBhLD_N6vXuAA5GuvXjiDFFPDE7SlNK4GQ'

# %%
URL = "https://api.spotify.com/v1/search"    # api-endpoint for searching
HEAD = {'Authorization': 'Bearer '+token}    # provide auth. crendtials

# %%
query = 'Rascal Flatts'
types = 'album,artist,track'

# %%
PARAMS = {'q': query, 'type':types}
response = r.get(url=URL, headers=HEAD, params=PARAMS).json()

# %%
len(response['albums']['items'])
# Out:
# 20

# %%
len(response['artists']['items'])
# Out:
# 5

# %%
len(response['tracks']['items'])
# Out:
# 20

# %%
response['tracks']['items']
# Out:
# [{'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'CH',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DZ',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'HK',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MY',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
# ...

# %%
t = types.split(',')
t
# Out:
# ['album', 'artist', 'track']

# %%
def search(query_str='', types='track'):  # only search for tracks for now
    token = get_token()
    URL = "https://api.spotify.com/v1/search"   
    HEAD = {'Authorization': 'Bearer '+token} 
    PARAMS = {'q': query_str, 'type':types}
    response = r.get(url=URL, headers=HEAD, params=PARAMS).json()
    for t in types.split(','):
        print(response[t+'s']['items'][0],'\n\n')

# %%
search('Jaden Thompson')
# Out:
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0mdzsyApmam6OqNr4Z3vKQ'}, 'href': 'https://api.spotify.com/v1/artists/0mdzsyApmam6OqNr4Z3vKQ', 'id': '0mdzsyApmam6OqNr4Z3vKQ', 'name': 'Jaden Thompson', 'type': 'artist', 'uri': 'spotify:artist:0mdzsyApmam6OqNr4Z3vKQ'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0sdHQM15v6W5ghn36Fegy0'}, 'href': 'https:
# ...
