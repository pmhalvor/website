# %% [markdown]
# # Audio Features KNN
# ## Strava API Client
#
# Now that the Spotify features are loaded into a pandas dataframe, a similar dataframe for our health data needs to be built. Over the scope of time we will be observing, all workouts have been uploaded to both Garmin Connect and Strava. The easiest API to integrate with is the Strava API, since no applications for approval are needed to get the initial credentials.
#
# In this notebook, we will:
# - Build a list of all activity ids and timeframes of workouts since March 2020
# - Match workout timeframe with recorded song history in `history.csv`
# - Build a dataframe including splits for each of the workouts. A split includes:
#     - Split time
#     - Split distance
#     - Average heart rate
#     - Elevation difference (optional)
#     - Average grade adjusted speed (optional)
# - A method to group track ids to split
#     - Catch overlapping song (belongs to two splits)
#
# Once these steps are complete, we can continue forward into building the model to cluster songs according to workout output.

# %% [markdown]
# # Set up notebook for local development

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tools import cd_to

cd_to(full_path="/Users/per.morten.halvorsen@schibsted.com/personal/website/radio")
# Out:
# Moving to /Users/per.morten.halvorsen@schibsted.com/personal/website/radio...
# Current working directory: /Users/per.morten.halvorsen@schibsted.com/personal/website/radio

# %% [markdown]
# # Authorize Strava API Client

# %% [markdown]
# Authorize via browser login:
# `https://www.strava.com/oauth/authorize?client_id=100479&client_secret=104b3ce334f234529230b7b940329c3493d68cb2&response_type=code&redirect_uri=http://perhalvorsen.com&approval_prompt=force&scope=activity:read_all`

# %% [markdown]
# POST `https://www.strava.com/oauth/token?client_id=100479&client_secret=104b3ce334f234529230b7b940329c3493d68cb2&code=846957b8031838ba77daed50a880152b38b1b551&grant_type=authorization_code`
#
#
# Response:<br/>
# ```
#     "refresh_token": "57e0108089eead9b4191b17314adaa3b208cd71a",
#     "access_token": "4c501d86c7b4903994614cbaa465b3f3a9ca1b79",
# ```

# %%
tokens = {
    "refresh_token": "57e0108089eead9b4191b17314adaa3b208cd71a",
    "access_token": "4c501d86c7b4903994614cbaa465b3f3a9ca1b79",
}

# %%
refresh = "5b3a271fcb4a958de7b9bf78f5ec3a24430c28fc"
client_id = "100479"
client_secret = "104b3ce334f234529230b7b940329c3493d68cb2"

# %%
from tools import refresh_access_token

tokens = refresh_access_token(
    client_id=client_id,
    client_secret=client_secret,
    refresh_token=tokens["refresh_token"],
)
# Out:
# Returned token info:
#  {'token_type': 'Bearer', 'access_token': '3931a00e2aa81c0054cf08affe27cffb6922a241', 'expires_at': 1678644428, 'expires_in': 11653, 'refresh_token': '57e0108089eead9b4191b17314adaa3b208cd71a'}

# %%
tokens
# Out:
# {'token_type': 'Bearer',
#  'access_token': '3931a00e2aa81c0054cf08affe27cffb6922a241',
#  'expires_at': 1678644428,
#  'expires_in': 11653,
#  'refresh_token': '57e0108089eead9b4191b17314adaa3b208cd71a'}

# %% [markdown]
# # Get Activity
#
# **List Athlete Activities (getLoggedInAthleteActivities)**<br/>
# Returns the activities of an athlete for a specific identifier.
#
# Requires
# - activity:read. Only Me activities will be filtered out unless requested by a token with activity:read_all.
#
# GET
# /athlete/activities
#
# **Parameters**<br/>
# - before:
# Integer, in query	An epoch timestamp to use for filtering activities that have taken place before a certain time.
# - after:
# Integer, in query	An epoch timestamp to use for filtering activities that have taken place after a certain time.
# - page:
# Integer, in query	Page number. Defaults to 1.
# - per_page:
# Integer, in query	Number of items per page. Defaults to 30.
#
# **Responses**<br/>
# - HTTP code 200	An array of SummaryActivity objects.
# - HTTP code 4xx, 5xx	A Fault describing the reason for the error.
#
#
# ```
# http GET
# "https://www.strava.com/api/v3/athlete/activities"
# "Authorization: Bearer [[token]]"
#
# params:
#     before=
#     after=
#     page=
#     per_page=
# ```

# %%
import requests

def get_athlete(
        access_token=tokens["access_token"],
        url = "https://www.strava.com/api/v3/athlete/",
    ):
    header = {"Authorization": f"Bearer {access_token}"}
    payload = {
        "activity": "read_all",
    }

    # post request
    response = requests.post(
        url=url,
        # data=payload,
        headers=header,
    )
    return response.json()

get_athlete()
# Out:
# {'id': 40990567,
#  'username': 'pmc_h',
#  'resource_state': 2,
#  'firstname': 'Per',
#  'lastname': 'Halvorsen',
#  'bio': 'A fish out of water.',
#  'city': 'Oslo',
#  'state': 'Norway',
#  'country': None,
#  'sex': 'M',
#  'premium': True,
#  'summit': True,
#  'created_at': '2019-04-11T08:04:45Z',
#  'updated_at': '2023-02-25T21:04:50Z',
#  'badge_type_id': 1,
#  'weight': 89.0,
#  'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/40990567/13168113/1/medium.jpg',
#  'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/40990567/13168113/1/large.jpg',
#  'friend': None,
#  'follower': None}

# %%
def get_activities(
        access_token=tokens["access_token"],
        url = "https://www.strava.com/api/v3/athlete/activities/",
    ):
    header = {"Authorization": f"Bearer {access_token}"}
    payload = {
        "activity": "read",
    }

    # post request
    response = requests.post(
        url=url,
        data=payload,
        headers=header,
    )
    return response.json()

activities = get_activities()

# %%
import json 

for i, activity in enumerate(activities):
    print(json.dumps(activity, indent=4))
    if i>4:
        break
# Out:
# {
#     "resource_state": 2,
#     "athlete": {
#         "id": 40990567,
#         "resource_state": 1
#     },
#     "name": "Afternoon Yoga",
#     "distance": 0.0,
#     "moving_time": 3286,
#     "elapsed_time": 3286,
#     "total_elevation_gain": 0,
#     "type": "Yoga",
#     "sport_type": "Yoga",
#     "id": 8697242695,
#     "start_date": "2023-03-11T15:10:54Z",
#     "start_date_local": "2023-03-11T16:10:54Z",
#     "timezone": "(GMT+01:00) Africa/Algiers",
#     "utc_offset": 3600.0,
#     "location_city": null,
#     "location_state": null,
#     "location_country": null,
#     "achievement_count": 0,
#     "kudos_count": 1,
#     "comment_count": 0,
#     "athlete_count": 1,
#     "photo_count": 0,
#     "map": {
#         "id": "a8697242695",
#         "summary_polyline": "",
#         "resource_state": 2
#     },
#     "trainer": true,
#     "commute": false,
#     "manual": false,
#     "private": false,
#     "visibility": "everyone",
#     "flagged": false,
#     "gear_id": null,
#     "start_latlng": [],
#     "end_latlng": [],
#     "average_speed": 0.0,
#     "max_speed": 0.0,
#     "average_temp": 29,
#     "has_heartrate": false,
#     "heartrate_opt_out": false,
#     "display_hide_heartrate_option": false,
#     "upload_id": 9335283190,
#     "upload_id_str": "9335283190",
#     "external_id": "garmin_ping_263886032400",
#     "from_accepted_tag": false,
#     "pr_count": 0,
#     "total_photo_count": 0,
#     "has_kudoed": false
# }
# {
#     "resource_state": 2,
#     "athlete": {
#         "id": 40990567,
#         "resource_state": 1
#     },
#     "name": "Evening Run",
#     "distance": 4231.1,
#     "moving_time": 1927,
#     "elapsed_time": 1927,
#     "total_elevation_gain": 0,
#     "type": "Run",
#     "sport_type": "Run",
#     "workout_type": null,
#     "id": 8692088056,
#     "start_date": "2023-03-10T17:08:06Z",
#     "start_date_local": "2023-03-10T18:08:06Z",
#     "timezone": "(GMT+01:00) Africa/Algiers",
#     "utc_offset": 3600.0,
#     "location_city": null,
#     "location_state": null,
#     "location_country": null,
#     "achievement_count": 0,
#     "kudos_count": 1,
#     "comment_count": 0,
#     "athlete_count": 1,
#     "photo_count": 0,
#     "map": {
#         "id": "a8692088056",
#         "summary_polyline": "",
#         "resource_state": 2
#     },
#     "trainer": true,
#     "commute": false,
#     "manual": false,
#     "private": false,
#     "visibility": "everyone",
#     "flagged": false,
#     "gear_id": null,
#     "start_latlng": [],
#     "end_latlng": [],
#     "average_speed": 2.196,
#     "max_speed": 2.983,
#     "average_cadence": 75.2,
#     "average_temp": 25,
#     "has_heartrate": true,
#     "average_heartrate": 148.1,
#     "max_heartrate": 167.0,
#     "heartrate_opt_out": false,
#     "display_hide_heartrate_option": true,
#     "upload_id": 9329874059,
#     "upload_id_str": "9329874059",
#     "external_id": "garmin_ping_263749317386",
#     "from_accepted_tag": false,
#     "pr_count": 0,
#     "total_photo_count": 0,
#     "has_kudoed": false,
#     "suffer_score": 17.0
# }
# {
#     "resource_state": 2,
#     "athlete": {
#         "id": 40990567,
#         "resource_state": 1
#     },
#     "name": "Evening Run",
#     "distance": 1694.0,
#     "moving_time": 967,
#     "elapsed_time": 967,
#     "total_elevation_gain": 0,
#     "type": "Run",
#     "sport_type": "Run",
#     "workout_type": 0,
#     "id": 8681946004,
#     "start_date": "2023-03-08T17:44:23Z",
#     "start_date_local": "2023-03-08T18:44:23Z",
#     "timezone": "(GMT+01:00) Africa/Algiers",
#     "utc_offset": 3600.0,
#     "location_city": null,
#     "location_state": null,
#     "location_country": null,
#     "achievement_count": 0,
#     "kudos_count": 0,
#     "comment_count": 0,
#     "athlete_count": 1,
#     "photo_count": 0,
#     "map": {
#         "id": "a8681946004",
#         "summary_polyline": "",
#         "resource_state": 2
#     },
#     "trainer": true,
#     "commute": false,
#     "manual": false,
#     "private": true,
#     "visibility": "only_me",
#     "flagged": false,
#     "gear_id": null,
#     "start_latlng": [],
#     "end_latlng": [],
#     "average_speed": 1.752,
#     "max_speed": 3.26,
#     "average_cadence": 70.2,
#     "average_temp": 24,
#     "has_heartrate": true,
#     "average_heartrate": 119.6,
#     "max_heartrate": 147.0,
#     "heartrate_opt_out": false,
#     "display_hide_heartrate_option": true,
#     "upload_id": 9319295822,
#     "upload_id_str": "9319295822",
#     "external_id": "garmin_ping_263453087251",
#     "from_accepted_tag": false,
#     "pr_count": 0,
#     "total_photo_count": 0,
#     "has_kudoed": false,
#     "suffer_score": 2.0
# }
# {
#     "resource_state": 2,
#     "athlete": {
#         "id": 40990567,
#         "resource_state": 1
#     },
#     "name": "Afternoon Run",
#     "distance": 8305.1,
#     "moving_time": 3236,
#     "elapsed_time": 3662,
#     "total_elevation_gain": 226.0,
#     "type": "Run",
#     "sport_type": "Run",
#     "workout_type": null,
#     "id": 8670834905,
#     "start_date": "2023-03-06T16:56:09Z",
#     "start_date_local": "2023-03-06T17:56:09Z",
#     "timezone": "(GMT+01:00) Europe/Oslo",
#     "utc_offset": 3600.0,
#     "location_city": null,
#     "location_state": null,
#     "location_country": null,
#     "achievement_count": 6,
#     "kudos_count": 6,
#     "comment_count": 0,
#     "athlete_count": 3,
#     "photo_count": 0,
#     "map": {
#         "id": "a8670834905",
#         "summary_polyline": "{oqlJwxbaAvBE|@Fr@JjBHP?^HL?hB_@tAIRE~FmAvA_@nBu@\\BLFRCh@[j@c@pAuA^]bAw@PK`@K\\]^Qp@@n@Ep@K`@M^AVI\\WRIrCO|CE|BIz@AP@n@?`@DbA@RGFEJARB?BEBBiADmARyAPk@\\aATa@j@s@b@UrA]nAOf@KxBO\\QN@IGYPSFwDd@YHeAPw@\\o@r@QVQ\\i@~ASnAEh@ElB?{@B{@Fg@VsAXeARe@`AoAZU`@S\\Kr@OdAMP@nBSt@SJKDMEZIFMEg@TeE^uAT[Jg@^i@t@]r@e@|AWnBGhA?n@BgBJqALo@T{@Xq@d@y@l@q@ZSpAa@p@C^GrAAt@IXIXQPSHYWj@GDOBGHOHeBJ]FKFe@Dq@\\}@HMDk@\\KP[Tm@hASp@Ml@APC@VkA\\kAb@u@h@i@f@WXKbCWQLeAH]HWDo@PUNo@`Ai@~AYrAHk@^yA\\y@`@i@VW^SnAYp@GK@MHIAs@Ju@V[Re@d@e@bAOd@Od@Kn@@DEFJu@`@uAZm@d@q@`@[`@Sh@OjAMe@PYBeAXa@R_@^UZ_@v@[dAQ`AFe@No@Z}@^u@TYl@i@\\OnAc@h@GEHWFYTM@MFO?w@R]Ri@r@Yl@c@~AOx@A[B?j@uBVo@R_@h@i@TMUTYPMNe@z@Y~@Qv@Kr@?GPmAb@uA^q@f@e@PMEFYNa@j@INm@dBKf@Ij@@STmAn@}Ab@i@l@k@WLURk@v@a@hAQt@Mv@X{ALc@^{@V_@p@g@VOABEASDWRi@p@e@fAUz@M~@f@_C^{@x@}@`@Y]Nm@l@m@pAYjAKl@R{@^eAr@mAt@q@g@TOLe@t@KRWv@WnA?G@@NgAVw@Rc@v@aAhAw@XIz@ONGf@?REbBM^I^QPM^mALaABa@CMGI_@QaA[[CYI[[k@QqAgAs@eASa@K[[oA_@aA",
#         "resource_state": 2
#     },
#     "trainer": false,
#     "commute": false,
#     "manual": false,
#     "private": false,
#     "visibility": "everyone",
#     "flagged": false,
#     "gear_id": null,
#     "start_latlng": [
#         59.89829778671265,
#         10.834661442786455
#     ],
#     "end_latlng": [
#         59.88409188576043,
#         10.845105713233352
#     ],
#     "average_speed": 2.566,
#     "max_speed": 7.204,
#     "average_cadence": 73.7,
#     "average_temp": 13,
#     "has_heartrate": true,
#     "average_heartrate": 152.7,
#     "max_heartrate": 188.0,
#     "heartrate_opt_out": false,
#     "display_hide_heartrate_option": true,
#     "elev_high": 165.8,
#     "elev_low": 114.8,
#     "upload_id": 9307675026,
#     "upload_id_str": "9307675026",
#     "external_id": "garmin_ping_263143463663",
#     "from_accepted_tag": false,
#     "pr_count": 1,
#     "total_photo_count": 0,
#     "has_kudoed": false,
#     "suffer_score": 38.0
# }
# {
#     "resource_state": 2,
#     "athlete": {
#         "id": 40990567,
#         "resource_state": 1
#     },
#     "name": "Afternoon Run",
#     "distance": 15549.5,
#     "moving_time": 4623,
#     "elapsed_time": 4623,
#     "total_elevation_gain": 112.0,
#     "type": "Run",
#     "sport_type": "Run",
#     "workout_type": null,
#     "id": 8665524768,
#     "start_date": "2023-03-05T15:08:59Z",
#     "start_date_local": "2023-03-05T16:08:59Z",
#     "timezone": "(GMT+01:00) Europe/Oslo",
#     "utc_offset": 3600.0,
#     "location_city": null,
#     "location_state": null,
#     "location_country": null,
#     "achievement_count": 10,
#     "kudos_count": 7,
#     "comment_count": 0,
#     "athlete_count": 1,
#     "photo_count": 0,
#     "map": {
#         "id": "a8665524768",
#         "summary_polyline": "i`tlJ_ez`A^xAPtAZxCJlCdBbMXnDPdB|BhLR|@NLp@i@ZmAIiAD_BEyALqA`AeDfAgGVs@|@gAZsBv@wRFeHLq@\\DN`B`@f@d@`@bA`@DXrAV\\ZJb@[|CFpAU|E@f@Ol@S[_Am@]DYj@GnA{@nFmAtTm@tBaAxE}@fJQ~DWn@OdB?h@Xj@@n@K|F[nG@~@Ll@G`AV?DNL~@PrDd@|C\\v@f@rCYlCi@rD_@rOo@zFq@bE?v@xBfBrNtHpBJnBc@hBy@f@|Af@ZPz@GfCyARyC`Do@b@IdBJx@|@lBhArB\\PHp@d@lBh@bANv@jAlCz@~CZ`CEn@[fAQTo@Eq@`Ai@^[OQm@Ew@k@s@y@mBq@_Ao@gBQ}@eAyBWHQ\\_BhAcCxA]So@eAyBcCo@a@{@?g@WWTWtA]|CWv@qAhJQj@{AsAyA{@]Rw@zEGvArApBzDnLhAbCTfApAtApAl@Xj@KjCXjAdAjAjA^\\\\\\lABh@MfALxBtCpBZtB@jAShFIz@U`AsBrBqA~Dg@rC[n@kB`BwAhAaBp@iBLi@KqGFiErA}@lAW~@cAhIa@tDAnBXbCb@zAZlDy@bEQjCBhAKjAHhCh@xBDl@JTPB@TO^MHEtGa@fG@nALnAn@VNd@DvBf@zBdB|Dh@`DZxFM|MuArV@Nj@bAg@pBy@pIf@qFIa@uBsC{@_B}EaGUiAcAuA}AwCe@sAkA{EcAiCUiACyAKg@MCQ[A_AUuCAaBi@aEKaBi@aCOyBc@qBWgCH_@BcARy@a@wADeFEkCLwF?eKLmI`@_@CsGzAqENs@VW^}DPaAL[JACeAVkAHmCg@mAo@{@XgAN_B`@sBxA_EXsD?c@o@eE}@sB[eEGUtBoGj@uBb@aAYEaAcAGSFo@n@wAD[CcAo@aB{AuB{AsDI}@^e@J]{@yAi@LMOAgAVcAu@cC\\aA|@iA~@wC?_@_@kB@c@x@uCAeANmADsAf@kB^cBFg@EiAIe@j@iD`@wFmCoBo@q@cAi@_BY_AqASu@`AyDlA}CfAmBd@wAfAgB`BkBpAeDjCcCf@gCFgCt@sD^}CDyDx@aFn@mCXsBxAsF|@{Ap@sCl@mDtB_Hh@I\\]dBeCNc@CmASg@{BsAi@eAY{AKwA_@iBkByDkCyCiDyC",
#         "resource_state": 2
#     },
#     "trainer": false,
#     "commute": false,
#     "manual": false,
#     "private": false,
#     "visibility": "everyone",
#     "flagged": false,
#     "gear_id": null,
#     "start_latlng": [
#         59.912121053785086,
#         10.79122256487608
#     ],
#     "end_latlng": [
#         59.91321514360607,
#         10.786362988874316
#     ],
#     "average_speed": 3.364,
#     "max_speed": 7.646,
#     "average_cadence": 78.4,
#     "average_temp": 21,
#     "has_heartrate": true,
#     "average_heartrate": 147.2,
#     "max_heartrate": 165.0,
#     "heartrate_opt_out": false,
#     "display_hide_heartrate_option": true,
#     "elev_high": 68.0,
#     "elev_low": 4.6,
#     "upload_id": 9302040616,
#     "upload_id_str": "9302040616",
#     "external_id": "garmin_ping_262963923633",
#     "from_accepted_tag": false,
#     "pr_count": 3,
#     "total_photo_count": 0,
#     "has_kudoed": false,
#     "suffer_score": 27.0
# }
# {
#     "resource_state": 2,
#     "athlete": {
#         "id": 40990567,
#         "resource_state": 1
#     },
#     "name": "Afternoon Run",
#     "distance": 10502.8,
#     "moving_time": 3307,
#     "elapsed_time": 3326,
#     "total_elevation_gain": 101.0,
#     "type": "Run",
#     "sport_type": "Run",
#     "workout_type": null,
#     "id": 8659413006,
#     "start_date": "2023-03-04T15:56:18Z",
#     "start_date_local": "2023-03-04T16:56:18Z",
#     "timezone": "(GMT+01:00) Europe/Oslo",
#     "utc_offset": 3600.0,
#     "location_city": null,
#     "location_state": null,
#     "location_country": null,
#     "achievement_count": 10,
#     "kudos_count": 9,
#     "comment_count": 0,
#     "athlete_count": 1,
#     "photo_count": 0,
#     "map": {
#         "id": "a8659413006",
#         "summary_polyline": "sctlJity`AZP`AhAXN\\LHHRl@Fb@t@fBDD\\@JDLhATpAF|@LfAJhA@^H`AVtAp@jAf@bBHNJvAA|@EHa@dAYb@_@f@_@TY`@SJOCk@e@[{@a@g@[U[g@u@uC]eAMg@U]m@_BOQWUIEa@c@OIa@YGKwBsB]MS[COQUSSGAMJUb@Ov@Kz@C^?zADvCBNH?PKhA[h@Ub@JNJp@l@n@r@tAvBb@VbARRHh@LHFNXRTh@\\T\\LZ^\\`@LZXLRMt@@LXMTk@f@y@hA}A^WH@Rf@VhBn@hDDr@H\\V`@HXXvBL|AI|E?vCGpBGd@E|A@bBHtBp@rHPnA^`Bx@fC@b@]nEJ`@AZMz@SjBe@rHA`Ai@lE}@fGEj@@DTZtAp@j@`@`EzBdBfA~CdBZFdB@~@Sp@Sp@_@\\QBBRZVp@^\\X`ADv@CbAFVp@RDDXr@f@jBZ`An@|Ap@hAhCvET`AVd@b@b@^L`@MPAdARpC?bAMlCu@zBgBPK^K\\a@\\cA\\s@f@u@h@m@r@q@z@eAFA}B~B{@fAe@v@Qd@Gd@GP[d@yAn@c@Xo@n@a@Tq@D_AXqBTiAAcBWe@?KD]I_@Wa@g@[qAqDmGa@_AQa@g@}Ag@iB[o@OMa@CeAPQJg@^gBnBYVQFY`@?r@HhADPt@xA`@jA~@tBtAzDfBnFT|@t@bE?t@Ul@?JGJGBYEQHg@|@q@t@_@GS}@[y@IO_@_@QKWc@g@oAUy@AMS}@Uo@_@u@SSWk@oAyDQaA[aAS{@A_A@s@TeCMgCFeBBQFANP@NRj@fCfBP@PkA~@k@|AaBp@k@NIt@STMAuBW}@WW_@Kc@oAK@sAn@s@Pg@Hm@BuAOyDwBu@g@{CwA{BsAwAs@IO@_@\\kCXqAf@gDPqABk@@yAXoDB}@?YIm@@QBiCBYBEJEJa@L_BLy@@i@Uu@Wk@q@wC_@cEMe@OgAA{CGyBTyEDuB@wC?{@B}@Cs@i@_EOo@GGC@S~AEjAKG?EBUDEJa@Jo@Ey@QgAWu@s@oDSm@KQBEScCUiAs@gC}AiJKyAQyAKqBUsCi@gEAUIi@SkCMw@S{@Ge@k@}C",
#         "resource_state": 2
#     },
#     "trainer": false,
#     "commute": false,
#     "manual": false,
#     "private": false,
#     "visibility": "everyone",
#     "flagged": false,
#     "gear_id": null,
#     "start_latlng": [
#         59.913312792778015,
#         10.786158805713058
#     ],
#     "end_latlng": [
#         59.913224363699555,
#         10.786225693300366
#     ],
#     "average_speed": 3.176,
#     "max_speed": 4.886,
#     "average_cadence": 77.2,
#     "average_temp": 19,
#     "has_heartrate": true,
#     "average_heartrate": 161.3,
#     "max_heartrate": 184.0,
#     "heartrate_opt_out": false,
#     "display_hide_heartrate_option": true,
#     "elev_high": 66.0,
#     "elev_low": 4.0,
#     "upload_id": 9295239916,
#     "upload_id_str": "9295239916",
#     "external_id": "garmin_ping_262810864735",
#     "from_accepted_tag": false,
#     "pr_count": 4,
#     "total_photo_count": 0,
#     "has_kudoed": false,
#     "suffer_score": 59.0
# }

# %%
import pandas as pd 

df = pd.DataFrame(activities)

ids = list(df.id[df.elapsed_time>1200])
len(ids)
# Out:
# 28

# %%
idx = ids.index(8670834905)
ids[idx]
# Out:
# 8670834905

# %%
def get_activity(
        access_token=tokens["access_token"],
        id=0,
        url = "https://www.strava.com/api/v3/activities/{id}/",
    ):
    header = {"Authorization": f"Bearer {access_token}"}
    payload = {
        "activity": "read",
    }

    # post request
    response = requests.post(
        url=url.format(id=id),
        data=payload,
        headers=header,
    )
    return response.json()

activity = get_activity(id=ids[idx])
activity
# Out:
# {'resource_state': 3,
#  'athlete': {'id': 40990567, 'resource_state': 1},
#  'name': 'Afternoon Run',
#  'distance': 8305.1,
#  'moving_time': 3236,
#  'elapsed_time': 3662,
#  'total_elevation_gain': 226.0,
#  'type': 'Run',
#  'sport_type': 'Run',
#  'workout_type': None,
#  'id': 8670834905,
#  'start_date': '2023-03-06T16:56:09Z',
#  'start_date_local': '2023-03-06T17:56:09Z',
#  'timezone': '(GMT+01:00) Europe/Oslo',
#  'utc_offset': 3600.0,
#  'location_city': None,
#  'location_state': None,
#  'location_country': None,
#  'achievement_count': 6,
#  'kudos_count': 6,
#  'comment_count': 0,
#  'athlete_count': 3,
#  'photo_count': 0,
#  'map': {'id': 'a8670834905',
#   'polyline': 'i{qlJsccaAl@NdAZd@BRCj@UX@JDNNVj@Jd@FnA?rABb@NTnAEdAA|@Fr@JjBHP?^HL?hB_@tAIvH_Br@SnBu@\\BLFRCh@[j@c@pAuA^]bAw@PK`@K\\]^Qp@@n@Ep@K`@M^AVI\\WRIzAKnKUP@n@?`@DbA@RGFEJARB?BEBBiADmARyAPk@\\aATa@j@s@b@UrA]nAOf@KxBO\\QN@IGYPSFwDd@YHeAPw@\\o@r@QVQ\\i@~ASnAEh@ElB?{@B{@Fg@VsAXeARe@`AoAZU`@S\\Kr@OdAMP@nBSt@SJKDMEZIFMEg@TeE^uAT[Jg@^i@t@]r@e@|AWnBGhA?n@BgBJqALo@T{@Xq@d@y@l@q@ZSpAa@p@C^GrAAt@IXIXQPSHYWj@GDOBGHOHeBJ]FKFe@Dq@\\}@HMDk@\\KP[Tm@hASp@Ml@APC@VkA\\kAb@u@h@i@f@WXKbCWQLeAH]HWDo@PUNo@`Ai@~AYrAHk@^yA\\y@`@i@VW^SnAYp@GK@MHIAs@Ju@V[Re@d@e@bAOd@Od@Kn@@DEFJu@`@uAZm@d@q@`@[`@Sh@OjAMe@PYBeAXa@R_@^UZ_@v@[dAQ`AFe@No@Z}@^u@TYl@i@\\OnAc@h@GEHWFYTM@MFO?w@R]Ri@r@Yl@c@~AOx@A[B?j@uBVo@R_@h@i@TMUTYPMNe@z@Y~@Qv@Kr@?GPmAb@uA^q@f@e@PMEFYNa@j@INm@dBKf@Ij@@STmAn@}Ab@i@l@k@WLURk@v@a@hAQt@Mv@X{ALc@^{@V_@p@g@VOABEASDWRi@p@e@fAUz@M~@f@_C^{@x@}@`@Y]Nm@l@m@pAYjAKl@R{@^eAr@mAt@q@g@TOLe@t@KRWv@WnA?G@@NgAVw@Rc@v@aAhAw@XIz@ONGf@?REbBM^Ip@_@^mALaABa@EOQOE?MIaA[[CYI[[k@QiA}@_AuA[w@[oA_@aAoAaFo@_DYoCM_AQu@^K@[Jc@LEDB?d@GNo@r@MBS_AOoALn@Ke@LhBBYA?GJAA?AFCDDHn@CJQ?@WAEBXLQ',
#   'resource_state': 3,
#   'summary_polyline': '{oqlJwxbaAvBE|@Fr@JjBHP?^HL?hB_@tAIRE~FmAvA_@nBu@\\BLFRCh@[j@c@pAuA^]bAw@PK`@K\\]^Qp@@n@Ep@K`@M^AVI\\WRIrCO|CE|BIz@AP@n@?`@DbA@RGFEJARB?BEBBiADmARyAPk@\\aATa@j@s@b@UrA]nAOf@KxBO\\QN@IGYPSFwDd@YHeAPw@\\o@r@QVQ\\i@~ASnAEh@ElB?{@B{@Fg@VsAXeARe@`AoAZU`@S\\Kr@OdAMP@nBSt@SJKDMEZIFMEg@TeE^uAT[Jg@^i@t@]r@e@|AWnBGhA?n@BgBJqALo@T{@Xq@d@y@l@q@ZSpAa@p@C^GrAAt@IXIXQPSHYWj@GDOBGHOHeBJ]FKFe@Dq@\\}@HMDk@\\KP[Tm@hASp@Ml@APC@VkA\\kAb@u@h@i@f@WXKbCWQLeAH]HWDo@PUNo@`Ai@~AYrAHk@^yA\\y@`@i@VW^SnAYp@GK@MHIAs@Ju@V[Re@d@e@bAOd@Od@Kn@@DEFJu@`@uAZm@d@q@`@[`@Sh@OjAMe@PYBeAXa@R_@^UZ_@v@[dAQ`AFe@No@Z}@^u@TYl@i@\\OnAc@h@GEHWFYTM@MFO?w@R]Ri@r@Yl@c@~AOx@A[B?j@uBVo@R_@h@i@TMUTYPMNe@z@Y~@Qv@Kr@?GPmAb@uA^q@f@e@PMEFYNa@j@INm@dBKf@Ij@@STmAn@}Ab@i@l@k@WLURk@v@a@hAQt@Mv@X{ALc@^{@V_@p@g@VOABEASDWRi@p@e@fAUz@M~@f@_C^{@x@}@`@Y]Nm@l@m@pAYjAKl@R{@^eAr@mAt@q@g@TOLe@t@KRWv@WnA?G@@NgAVw@Rc@v@aAhAw@XIz@ONGf@?REbBM^I^QPM^mALaABa@CMGI_@QaA[[CYI[[k@QqAgAs@eASa@K[[oA_@aA'},
#  'trainer': False,
#  'commute': False,
#  'manual': False,
#  'private': False,
#  'visibility': 'everyone',
#  'flagged': False,
#  'gear_id': None,
#  'start_latlng': [59.89829778671265, 10.834661442786455],
#  'end_latlng': [59.88409188576043, 10.845105713233352],
#  'average_speed': 2.566,
#  'max_speed': 7.204,
#  'average_cadence': 73.7,
#  'average_temp': 13,
#  'has_heartrate': True,
#  'average_heartrate': 152.7,
#  'max_heartrate': 188.0,
#  'heartrate_opt_out': False,
#  'display_hide_heartrate_option': True,
#  'elev_high': 165.8,
#  'elev_low': 114.8,
#  'upload_id': 9307675026,
#  'upload_id_str': '9307675026',
#  'external_id': 'garmin_ping_263143463663',
#  'from_accepted_tag': False,
#  'pr_count': 1,
#  'total_photo_count': 0,
#  'has_kudoed': False,
#  'suffer_score': 38.0,
#  'description': None,
#  'calories': 771.0,
#  'perceived_exertion': None,
#  'prefer_perceived_exertion': None,
#  'segment_efforts': [{'id': 3067885232728180660,
#    'resource_state': 2,
#    'name': 'Asfaltfortau opp til Østensjø Gård',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 131,
#    'moving_time': 131,
#    'start_date': '2023-03-06T16:59:41Z',
#    'start_date_local': '2023-03-06T17:59:41Z',
#    'distance': 443.2,
#    'start_index': 70,
#    'end_index': 115,
#    'average_cadence': 79.6,
#    'device_watts': False,
#    'average_heartrate': 148.4,
#    'max_heartrate': 154.0,
#    'segment': {'id': 8741619,
#     'resource_state': 2,
#     'name': 'Asfaltfortau opp til Østensjø Gård',
#     'activity_type': 'Run',
#     'distance': 443.2,
#     'average_grade': 5.2,
#     'maximum_grade': 9.4,
#     'elevation_high': 169.4,
#     'elevation_low': 145.4,
#     'start_latlng': [59.892097, 10.833141],
#     'end_latlng': [59.888327, 10.835374],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Oslo',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': False},
#    'pr_rank': None,
#    'achievements': [],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232727221172,
#    'resource_state': 2,
#    'name': 'Opp Eterveien til Bogerudveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 320,
#    'moving_time': 126,
#    'start_date': '2023-03-06T17:04:04Z',
#    'start_date_local': '2023-03-06T18:04:04Z',
#    'distance': 389.8,
#    'start_index': 153,
#    'end_index': 210,
#    'average_cadence': 51.8,
#    'device_watts': False,
#    'average_heartrate': 126.3,
#    'max_heartrate': 178.0,
#    'segment': {'id': 13729413,
#     'resource_state': 2,
#     'name': 'Opp Eterveien til Bogerudveien',
#     'activity_type': 'Run',
#     'distance': 389.8,
#     'average_grade': 5.9,
#     'maximum_grade': 16.3,
#     'elevation_high': 136.8,
#     'elevation_low': 113.4,
#     'start_latlng': [59.883999, 10.8358],
#     'end_latlng': [59.881067, 10.838527],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Oslo',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': False},
#    'pr_rank': 3,
#    'achievements': [{'type_id': 3, 'type': 'pr', 'rank': 3}],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232725824436,
#    'resource_state': 2,
#    'name': 'Kort bakkedrag - Eterveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 58,
#    'moving_time': 58,
#    'start_date': '2023-03-06T17:07:48Z',
#    'start_date_local': '2023-03-06T18:07:48Z',
#    'distance': 199.8,
#    'start_index': 179,
#    'end_index': 199,
#    'average_cadence': 77.0,
#    'device_watts': False,
#    'average_heartrate': 163.2,
#    'max_heartrate': 176.0,
#    'segment': {'id': 23310683,
#     'resource_state': 2,
#     'name': 'Kort bakkedrag - Eterveien',
#     'activity_type': 'Run',
#     'distance': 199.8,
#     'average_grade': 7.0,
#     'maximum_grade': 7.5,
#     'elevation_high': 127.6,
#     'elevation_low': 113.6,
#     'start_latlng': [59.883738, 10.837338],
#     'end_latlng': [59.882096, 10.838495],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': True},
#    'pr_rank': None,
#    'achievements': [],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232725657524,
#    'resource_state': 2,
#    'name': 'Opp Eterveien til Bogerudveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 193,
#    'moving_time': 106,
#    'start_date': '2023-03-06T17:11:55Z',
#    'start_date_local': '2023-03-06T18:11:55Z',
#    'distance': 389.8,
#    'start_index': 258,
#    'end_index': 306,
#    'average_cadence': 43.6,
#    'device_watts': False,
#    'average_heartrate': 134.1,
#    'max_heartrate': 183.0,
#    'segment': {'id': 13729413,
#     'resource_state': 2,
#     'name': 'Opp Eterveien til Bogerudveien',
#     'activity_type': 'Run',
#     'distance': 389.8,
#     'average_grade': 5.9,
#     'maximum_grade': 16.3,
#     'elevation_high': 136.8,
#     'elevation_low': 113.4,
#     'start_latlng': [59.883999, 10.8358],
#     'end_latlng': [59.881067, 10.838527],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Oslo',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': False},
#    'pr_rank': 2,
#    'achievements': [{'type_id': 3, 'type': 'pr', 'rank': 2}],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232728358836,
#    'resource_state': 2,
#    'name': 'Kort bakkedrag - Eterveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 54,
#    'moving_time': 54,
#    'start_date': '2023-03-06T17:13:45Z',
#    'start_date_local': '2023-03-06T18:13:45Z',
#    'distance': 199.8,
#    'start_index': 272,
#    'end_index': 293,
#    'average_cadence': 77.8,
#    'device_watts': False,
#    'average_heartrate': 165.9,
#    'max_heartrate': 177.0,
#    'segment': {'id': 23310683,
#     'resource_state': 2,
#     'name': 'Kort bakkedrag - Eterveien',
#     'activity_type': 'Run',
#     'distance': 199.8,
#     'average_grade': 7.0,
#     'maximum_grade': 7.5,
#     'elevation_high': 127.6,
#     'elevation_low': 113.6,
#     'start_latlng': [59.883738, 10.837338],
#     'end_latlng': [59.882096, 10.838495],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': True},
#    'pr_rank': None,
#    'achievements': [],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232727753652,
#    'resource_state': 2,
#    'name': 'Opp Eterveien til Bogerudveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 121,
#    'moving_time': 115,
#    'start_date': '2023-03-06T17:17:53Z',
#    'start_date_local': '2023-03-06T18:17:53Z',
#    'distance': 389.8,
#    'start_index': 367,
#    'end_index': 407,
#    'average_cadence': 75.9,
#    'device_watts': False,
#    'average_heartrate': 166.1,
#    'max_heartrate': 180.0,
#    'segment': {'id': 13729413,
#     'resource_state': 2,
#     'name': 'Opp Eterveien til Bogerudveien',
#     'activity_type': 'Run',
#     'distance': 389.8,
#     'average_grade': 5.9,
#     'maximum_grade': 16.3,
#     'elevation_high': 136.8,
#     'elevation_low': 113.4,
#     'start_latlng': [59.883999, 10.8358],
#     'end_latlng': [59.881067, 10.838527],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Oslo',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': False},
#    'pr_rank': 1,
#    'achievements': [{'type_id': 3, 'type': 'pr', 'rank': 1}],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232727808948,
#    'resource_state': 2,
#    'name': 'Kort bakkedrag - Eterveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 59,
#    'moving_time': 59,
#    'start_date': '2023-03-06T17:18:20Z',
#    'start_date_local': '2023-03-06T18:18:20Z',
#    'distance': 199.8,
#    'start_index': 380,
#    'end_index': 398,
#    'average_cadence': 78.3,
#    'device_watts': False,
#    'average_heartrate': 169.6,
#    'max_heartrate': 177.0,
#    'segment': {'id': 23310683,
#     'resource_state': 2,
#     'name': 'Kort bakkedrag - Eterveien',
#     'activity_type': 'Run',
#     'distance': 199.8,
#     'average_grade': 7.0,
#     'maximum_grade': 7.5,
#     'elevation_high': 127.6,
#     'elevation_low': 113.6,
#     'start_latlng': [59.883738, 10.837338],
#     'end_latlng': [59.882096, 10.838495],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': True},
#    'pr_rank': None,
#    'achievements': [],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232726295476,
#    'resource_state': 2,
#    'name': 'Kort bakkedrag - Eterveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 40,
#    'moving_time': 40,
#    'start_date': '2023-03-06T17:25:13Z',
#    'start_date_local': '2023-03-06T18:25:13Z',
#    'distance': 199.8,
#    'start_index': 522,
#    'end_index': 549,
#    'average_cadence': 86.3,
#    'device_watts': False,
#    'average_heartrate': 163.7,
#    'max_heartrate': 179.0,
#    'segment': {'id': 23310683,
#     'resource_state': 2,
#     'name': 'Kort bakkedrag - Eterveien',
#     'activity_type': 'Run',
#     'distance': 199.8,
#     'average_grade': 7.0,
#     'maximum_grade': 7.5,
#     'elevation_high': 127.6,
#     'elevation_low': 113.6,
#     'start_latlng': [59.883738, 10.837338],
#     'end_latlng': [59.882096, 10.838495],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': True},
#    'pr_rank': 3,
#    'achievements': [{'type_id': 3, 'type': 'pr', 'rank': 3}],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232727132084,
#    'resource_state': 2,
#    'name': 'Kort bakkedrag - Eterveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 39,
#    'moving_time': 39,
#    'start_date': '2023-03-06T17:27:21Z',
#    'start_date_local': '2023-03-06T18:27:21Z',
#    'distance': 199.8,
#    'start_index': 580,
#    'end_index': 600,
#    'average_cadence': 85.0,
#    'device_watts': False,
#    'average_heartrate': 178.0,
#    'max_heartrate': 186.0,
#    'segment': {'id': 23310683,
#     'resource_state': 2,
#     'name': 'Kort bakkedrag - Eterveien',
#     'activity_type': 'Run',
#     'distance': 199.8,
#     'average_grade': 7.0,
#     'maximum_grade': 7.5,
#     'elevation_high': 127.6,
#     'elevation_low': 113.6,
#     'start_latlng': [59.883738, 10.837338],
#     'end_latlng': [59.882096, 10.838495],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': True},
#    'pr_rank': 2,
#    'achievements': [{'type_id': 3, 'type': 'pr', 'rank': 2}],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232725845940,
#    'resource_state': 2,
#    'name': 'Kort bakkedrag - Eterveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 38,
#    'moving_time': 38,
#    'start_date': '2023-03-06T17:29:37Z',
#    'start_date_local': '2023-03-06T18:29:37Z',
#    'distance': 199.8,
#    'start_index': 637,
#    'end_index': 659,
#    'average_cadence': 89.4,
#    'device_watts': False,
#    'average_heartrate': 175.9,
#    'max_heartrate': 187.0,
#    'segment': {'id': 23310683,
#     'resource_state': 2,
#     'name': 'Kort bakkedrag - Eterveien',
#     'activity_type': 'Run',
#     'distance': 199.8,
#     'average_grade': 7.0,
#     'maximum_grade': 7.5,
#     'elevation_high': 127.6,
#     'elevation_low': 113.6,
#     'start_latlng': [59.883738, 10.837338],
#     'end_latlng': [59.882096, 10.838495],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': True},
#    'pr_rank': None,
#    'achievements': [{'type_id': 2, 'type': 'overall', 'rank': 7}],
#    'kom_rank': 7,
#    'hidden': False},
#   {'id': 3067885232726628276,
#    'resource_state': 2,
#    'name': 'Kort bakkedrag - Eterveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 59,
#    'moving_time': 58,
#    'start_date': '2023-03-06T17:31:20Z',
#    'start_date_local': '2023-03-06T18:31:20Z',
#    'distance': 199.8,
#    'start_index': 679,
#    'end_index': 706,
#    'average_cadence': 84.0,
#    'device_watts': False,
#    'average_heartrate': 172.0,
#    'max_heartrate': 188.0,
#    'segment': {'id': 23310683,
#     'resource_state': 2,
#     'name': 'Kort bakkedrag - Eterveien',
#     'activity_type': 'Run',
#     'distance': 199.8,
#     'average_grade': 7.0,
#     'maximum_grade': 7.5,
#     'elevation_high': 127.6,
#     'elevation_low': 113.6,
#     'start_latlng': [59.883738, 10.837338],
#     'end_latlng': [59.882096, 10.838495],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': True},
#    'pr_rank': None,
#    'achievements': [],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232726304692,
#    'resource_state': 2,
#    'name': 'Eterbakken',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 461,
#    'moving_time': 314,
#    'start_date': '2023-03-06T17:44:14Z',
#    'start_date_local': '2023-03-06T18:44:14Z',
#    'distance': 627.1,
#    'start_index': 957,
#    'end_index': 1087,
#    'average_cadence': 45.4,
#    'device_watts': False,
#    'average_heartrate': 138.1,
#    'max_heartrate': 163.0,
#    'segment': {'id': 6385257,
#     'resource_state': 2,
#     'name': 'Eterbakken',
#     'activity_type': 'Run',
#     'distance': 627.1,
#     'average_grade': 6.0,
#     'maximum_grade': 17.5,
#     'elevation_high': 151.5,
#     'elevation_low': 113.8,
#     'start_latlng': [59.88391, 10.836272],
#     'end_latlng': [59.88261, 10.840909],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Oslo',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': False},
#    'pr_rank': None,
#    'achievements': [],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232727206836,
#    'resource_state': 2,
#    'name': 'Kort bakkedrag - Eterveien',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 86,
#    'moving_time': 86,
#    'start_date': '2023-03-06T17:46:45Z',
#    'start_date_local': '2023-03-06T18:46:45Z',
#    'distance': 199.8,
#    'start_index': 994,
#    'end_index': 1021,
#    'average_cadence': 74.6,
#    'device_watts': False,
#    'average_heartrate': 146.6,
#    'max_heartrate': 158.0,
#    'segment': {'id': 23310683,
#     'resource_state': 2,
#     'name': 'Kort bakkedrag - Eterveien',
#     'activity_type': 'Run',
#     'distance': 199.8,
#     'average_grade': 7.0,
#     'maximum_grade': 7.5,
#     'elevation_high': 127.6,
#     'elevation_low': 113.6,
#     'start_latlng': [59.883738, 10.837338],
#     'end_latlng': [59.882096, 10.838495],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': True},
#    'pr_rank': None,
#    'achievements': [],
#    'kom_rank': None,
#    'hidden': False},
#   {'id': 3067885232727556020,
#    'resource_state': 2,
#    'name': 'GR Miniclimb',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 197,
#    'moving_time': 197,
#    'start_date': '2023-03-06T17:49:43Z',
#    'start_date_local': '2023-03-06T18:49:43Z',
#    'distance': 404.7,
#    'start_index': 1050,
#    'end_index': 1113,
#    'average_cadence': 59.7,
#    'device_watts': False,
#    'average_heartrate': 134.8,
#    'max_heartrate': 160.0,
#    'segment': {'id': 27560403,
#     'resource_state': 2,
#     'name': 'GR Miniclimb',
#     'activity_type': 'Run',
#     'distance': 404.7,
#     'average_grade': 3.3,
#     'maximum_grade': 5.5,
#     'elevation_high': 152.7,
#     'elevation_low': 139.3,
#     'start_latlng': [59.880755, 10.839942],
#     'end_latlng': [59.883448, 10.843949],
#     'elevation_profile': None,
#     'climb_category': 0,
#     'city': 'Bydel Østensjø',
#     'state': 'Oslo',
#     'country': 'Norway',
#     'private': False,
#     'hazardous': False,
#     'starred': False},
#    'pr_rank': None,
#    'achievements': [],
#    'kom_rank': None,
#    'hidden': False}],
#  'splits_metric': [{'distance': 1001.6,
#    'elapsed_time': 282,
#    'elevation_difference': 3.8,
#    'moving_time': 282,
#    'split': 1,
#    'average_speed': 3.55,
#    'average_grade_adjusted_speed': 3.68,
#    'average_heartrate': 139.69858156028369,
#    'pace_zone': 3},
#   {'distance': 998.5,
#    'elapsed_time': 480,
#    'elevation_difference': 6.0,
#    'moving_time': 302,
#    'split': 2,
#    'average_speed': 3.31,
#    'average_grade_adjusted_speed': 3.55,
#    'average_heartrate': 156.36713286713288,
#    'pace_zone': 2},
#   {'distance': 1001.5,
#    'elapsed_time': 451,
#    'elevation_difference': -1.0,
#    'moving_time': 364,
#    'split': 3,
#    'average_speed': 2.75,
#    'average_grade_adjusted_speed': 3.0,
#    'average_heartrate': 150.1939393939394,
#    'pace_zone': 1},
#   {'distance': 1000.2,
#    'elapsed_time': 457,
#    'elevation_difference': -14.4,
#    'moving_time': 454,
#    'split': 4,
#    'average_speed': 2.2,
#    'average_grade_adjusted_speed': 2.27,
#    'average_heartrate': 133.1647331786543,
#    'pace_zone': 1},
#   {'distance': 1007.0,
#    'elapsed_time': 367,
#    'elevation_difference': 7.8,
#    'moving_time': 310,
#    'split': 5,
#    'average_speed': 3.25,
#    'average_grade_adjusted_speed': 3.63,
#    'average_heartrate': 165.11724137931034,
#    'pace_zone': 3},
#   {'distance': 992.1,
#    'elapsed_time': 451,
#    'elevation_difference': -3.0,
#    'moving_time': 349,
#    'split': 6,
#    'average_speed': 2.84,
#    'average_grade_adjusted_speed': 3.04,
#    'average_heartrate': 166.30573248407643,
#    'pace_zone': 1},
#   {'distance': 1002.5,
#    'elapsed_time': 351,
#    'elevation_difference': 1.2,
#    'moving_time': 351,
#    'split': 7,
#    'average_speed': 2.86,
#    'average_grade_adjusted_speed': 3.09,
#    'average_heartrate': 175.5670731707317,
#    'pace_zone': 1},
#   {'distance': 997.7,
#    'elapsed_time': 606,
#    'elevation_difference': 33.8,
#    'moving_time': 606,
#    'split': 8,
#    'average_speed': 1.65,
#    'average_grade_adjusted_speed': 1.89,
#    'average_heartrate': 147.15824175824176,
#    'pace_zone': 1},
#   {'distance': 304.0,
#    'elapsed_time': 218,
#    'elevation_difference': 4.2,
#    'moving_time': 218,
#    'split': 9,
#    'average_speed': 1.39,
#    'average_grade_adjusted_speed': 1.64,
#    'average_heartrate': 145.98692810457516,
#    'pace_zone': 1}],
#  'splits_standard': [{'distance': 1610.2,
#    'elapsed_time': 454,
#    'elevation_difference': 2.4,
#    'moving_time': 454,
#    'split': 1,
#    'average_speed': 3.55,
#    'average_grade_adjusted_speed': 3.66,
#    'average_heartrate': 146.16960352422907,
#    'pace_zone': 3},
#   {'distance': 1617.1,
#    'elapsed_time': 833,
#    'elevation_difference': -7.4,
#    'moving_time': 568,
#    'split': 2,
#    'average_speed': 2.85,
#    'average_grade_adjusted_speed': 3.07,
#    'average_heartrate': 148.6949806949807,
#    'pace_zone': 1},
#   {'distance': 1604.2,
#    'elapsed_time': 697,
#    'elevation_difference': -0.6,
#    'moving_time': 637,
#    'split': 3,
#    'average_speed': 2.52,
#    'average_grade_adjusted_speed': 2.72,
#    'average_heartrate': 146.4884488448845,
#    'pace_zone': 1},
#   {'distance': 1609.5,
#    'elapsed_time': 654,
#    'elevation_difference': 1.6,
#    'moving_time': 552,
#    'split': 4,
#    'average_speed': 2.92,
#    'average_grade_adjusted_speed': 3.15,
#    'average_heartrate': 168.874,
#    'pace_zone': 2},
#   {'distance': 1608.5,
#    'elapsed_time': 831,
#    'elevation_difference': 40.8,
#    'moving_time': 831,
#    'split': 5,
#    'average_speed': 1.94,
#    'average_grade_adjusted_speed': 2.21,
#    'average_heartrate': 155.44596651445966,
#    'pace_zone': 1},
#   {'distance': 255.6,
#    'elapsed_time': 194,
#    'elevation_difference': 1.6,
#    'moving_time': 194,
#    'split': 6,
#    'average_speed': 1.32,
#    'average_grade_adjusted_speed': 1.49,
#    'average_heartrate': 144.2910447761194,
#    'pace_zone': 1}],
#  'laps': [{'id': 29346036903,
#    'resource_state': 2,
#    'name': 'Lap 1',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 281,
#    'moving_time': 281,
#    'start_date': '2023-03-06T16:56:09Z',
#    'start_date_local': '2023-03-06T17:56:09Z',
#    'distance': 1000.0,
#    'start_index': 0,
#    'end_index': 65,
#    'total_elevation_gain': 15.2,
#    'average_speed': 3.56,
#    'max_speed': 4.098,
#    'average_cadence': 82.0,
#    'device_watts': False,
#    'average_heartrate': 139.7,
#    'max_heartrate': 150.0,
#    'lap_index': 1,
#    'split': 1,
#    'pace_zone': 2},
#   {'id': 29346036906,
#    'resource_state': 2,
#    'name': 'Lap 2',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 397,
#    'moving_time': 219,
#    'start_date': '2023-03-06T17:00:54Z',
#    'start_date_local': '2023-03-06T18:00:54Z',
#    'distance': 709.73,
#    'start_index': 66,
#    'end_index': 137,
#    'total_elevation_gain': 9.6,
#    'average_speed': 3.24,
#    'max_speed': 4.287,
#    'average_cadence': 79.5,
#    'device_watts': False,
#    'average_heartrate': 156.4,
#    'max_heartrate': 166.0,
#    'lap_index': 2,
#    'split': 2,
#    'pace_zone': 2},
#   {'id': 29346036909,
#    'resource_state': 2,
#    'name': 'Lap 3',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 111,
#    'moving_time': 111,
#    'start_date': '2023-03-06T17:07:30Z',
#    'start_date_local': '2023-03-06T18:07:30Z',
#    'distance': 376.11,
#    'start_index': 138,
#    'end_index': 178,
#    'total_elevation_gain': 23.2,
#    'average_speed': 3.39,
#    'max_speed': 4.564,
#    'average_cadence': 76.8,
#    'device_watts': False,
#    'average_heartrate': 162.2,
#    'max_heartrate': 177.0,
#    'lap_index': 3,
#    'split': 3,
#    'pace_zone': 2},
#   {'id': 29346036910,
#    'resource_state': 2,
#    'name': 'Lap 4',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 28,
#    'moving_time': 28,
#    'start_date': '2023-03-06T17:09:22Z',
#    'start_date_local': '2023-03-06T18:09:22Z',
#    'distance': 15.79,
#    'start_index': 179,
#    'end_index': 188,
#    'total_elevation_gain': 0.0,
#    'average_speed': 0.56,
#    'max_speed': 2.64,
#    'average_cadence': 45.0,
#    'device_watts': False,
#    'average_heartrate': 174.7,
#    'max_heartrate': 178.0,
#    'lap_index': 4,
#    'split': 4,
#    'pace_zone': 1},
#   {'id': 29346036911,
#    'resource_state': 2,
#    'name': 'Lap 5',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 125,
#    'moving_time': 125,
#    'start_date': '2023-03-06T17:09:50Z',
#    'start_date_local': '2023-03-06T18:09:50Z',
#    'distance': 373.64,
#    'start_index': 189,
#    'end_index': 228,
#    'total_elevation_gain': 0.0,
#    'average_speed': 2.99,
#    'max_speed': 3.432,
#    'average_cadence': 76.9,
#    'device_watts': False,
#    'average_heartrate': 131.9,
#    'max_heartrate': 154.0,
#    'lap_index': 5,
#    'split': 5,
#    'pace_zone': 1},
#   {'id': 29346036914,
#    'resource_state': 2,
#    'name': 'Lap 6',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 195,
#    'moving_time': 109,
#    'start_date': '2023-03-06T17:13:22Z',
#    'start_date_local': '2023-03-06T18:13:22Z',
#    'distance': 386.65,
#    'start_index': 229,
#    'end_index': 278,
#    'total_elevation_gain': 21.2,
#    'average_speed': 3.55,
#    'max_speed': 4.208,
#    'average_cadence': 79.3,
#    'device_watts': False,
#    'average_heartrate': 161.1,
#    'max_heartrate': 183.0,
#    'lap_index': 6,
#    'split': 6,
#    'pace_zone': 2},
#   {'id': 29346036916,
#    'resource_state': 2,
#    'name': 'Lap 7',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 28,
#    'moving_time': 28,
#    'start_date': '2023-03-06T17:15:12Z',
#    'start_date_local': '2023-03-06T18:15:12Z',
#    'distance': 32.94,
#    'start_index': 279,
#    'end_index': 290,
#    'total_elevation_gain': 0.0,
#    'average_speed': 1.18,
#    'max_speed': 3.411,
#    'average_cadence': 50.9,
#    'device_watts': False,
#    'average_heartrate': 176.5,
#    'max_heartrate': 183.0,
#    'lap_index': 7,
#    'split': 7,
#    'pace_zone': 1},
#   {'id': 29346036918,
#    'resource_state': 2,
#    'name': 'Lap 8',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 144,
#    'moving_time': 141,
#    'start_date': '2023-03-06T17:15:40Z',
#    'start_date_local': '2023-03-06T18:15:40Z',
#    'distance': 379.41,
#    'start_index': 291,
#    'end_index': 343,
#    'total_elevation_gain': 0.0,
#    'average_speed': 2.69,
#    'max_speed': 3.368,
#    'average_cadence': 75.0,
#    'device_watts': False,
#    'average_heartrate': 134.7,
#    'max_heartrate': 164.0,
#    'lap_index': 8,
#    'split': 8,
#    'pace_zone': 1},
#   {'id': 29346036920,
#    'resource_state': 2,
#    'name': 'Lap 9',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 115,
#    'moving_time': 115,
#    'start_date': '2023-03-06T17:18:05Z',
#    'start_date_local': '2023-03-06T18:18:05Z',
#    'distance': 380.76,
#    'start_index': 344,
#    'end_index': 379,
#    'total_elevation_gain': 19.6,
#    'average_speed': 3.31,
#    'max_speed': 4.017,
#    'average_cadence': 77.4,
#    'device_watts': False,
#    'average_heartrate': 169.8,
#    'max_heartrate': 180.0,
#    'lap_index': 9,
#    'split': 9,
#    'pace_zone': 2},
#   {'id': 29346036922,
#    'resource_state': 2,
#    'name': 'Lap 10',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 306,
#    'moving_time': 249,
#    'start_date': '2023-03-06T17:20:01Z',
#    'start_date_local': '2023-03-06T18:20:01Z',
#    'distance': 353.28,
#    'start_index': 380,
#    'end_index': 487,
#    'total_elevation_gain': 0.0,
#    'average_speed': 1.42,
#    'max_speed': 2.601,
#    'average_cadence': 53.4,
#    'device_watts': False,
#    'average_heartrate': 113.7,
#    'max_heartrate': 179.0,
#    'lap_index': 10,
#    'split': 10,
#    'pace_zone': 1},
#   {'id': 29346036923,
#    'resource_state': 2,
#    'name': 'Lap 11',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 44,
#    'moving_time': 44,
#    'start_date': '2023-03-06T17:25:08Z',
#    'start_date_local': '2023-03-06T18:25:08Z',
#    'distance': 201.5,
#    'start_index': 488,
#    'end_index': 518,
#    'total_elevation_gain': 13.0,
#    'average_speed': 4.58,
#    'max_speed': 5.772,
#    'average_cadence': 87.1,
#    'device_watts': False,
#    'average_heartrate': 156.0,
#    'max_heartrate': 178.0,
#    'lap_index': 11,
#    'split': 11,
#    'pace_zone': 5},
#   {'id': 29346036924,
#    'resource_state': 2,
#    'name': 'Lap 12',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 83,
#    'moving_time': 83,
#    'start_date': '2023-03-06T17:25:53Z',
#    'start_date_local': '2023-03-06T18:25:53Z',
#    'distance': 232.28,
#    'start_index': 519,
#    'end_index': 546,
#    'total_elevation_gain': 2.4,
#    'average_speed': 2.8,
#    'max_speed': 3.384,
#    'average_cadence': 75.3,
#    'device_watts': False,
#    'average_heartrate': 166.0,
#    'max_heartrate': 180.0,
#    'lap_index': 12,
#    'split': 12,
#    'pace_zone': 1},
#   {'id': 29346036926,
#    'resource_state': 2,
#    'name': 'Lap 13',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 42,
#    'moving_time': 42,
#    'start_date': '2023-03-06T17:27:15Z',
#    'start_date_local': '2023-03-06T18:27:15Z',
#    'distance': 183.8,
#    'start_index': 547,
#    'end_index': 567,
#    'total_elevation_gain': 11.2,
#    'average_speed': 4.38,
#    'max_speed': 5.168,
#    'average_cadence': 85.6,
#    'device_watts': False,
#    'average_heartrate': 174.9,
#    'max_heartrate': 184.0,
#    'lap_index': 13,
#    'split': 13,
#    'pace_zone': 5},
#   {'id': 29346036927,
#    'resource_state': 2,
#    'name': 'Lap 14',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 94,
#    'moving_time': 94,
#    'start_date': '2023-03-06T17:27:57Z',
#    'start_date_local': '2023-03-06T18:27:57Z',
#    'distance': 212.66,
#    'start_index': 568,
#    'end_index': 603,
#    'total_elevation_gain': 0.0,
#    'average_speed': 2.26,
#    'max_speed': 4.184,
#    'average_cadence': 73.1,
#    'device_watts': False,
#    'average_heartrate': 165.1,
#    'max_heartrate': 186.0,
#    'lap_index': 14,
#    'split': 14,
#    'pace_zone': 1},
#   {'id': 29346036928,
#    'resource_state': 2,
#    'name': 'Lap 15',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 40,
#    'moving_time': 40,
#    'start_date': '2023-03-06T17:29:32Z',
#    'start_date_local': '2023-03-06T18:29:32Z',
#    'distance': 187.09,
#    'start_index': 604,
#    'end_index': 627,
#    'total_elevation_gain': 10.2,
#    'average_speed': 4.68,
#    'max_speed': 5.244,
#    'average_cadence': 90.5,
#    'device_watts': False,
#    'average_heartrate': 172.0,
#    'max_heartrate': 185.0,
#    'lap_index': 15,
#    'split': 15,
#    'pace_zone': 6},
#   {'id': 29346036929,
#    'resource_state': 2,
#    'name': 'Lap 16',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 82,
#    'moving_time': 82,
#    'start_date': '2023-03-06T17:30:12Z',
#    'start_date_local': '2023-03-06T18:30:12Z',
#    'distance': 214.42,
#    'start_index': 628,
#    'end_index': 654,
#    'total_elevation_gain': 0.0,
#    'average_speed': 2.61,
#    'max_speed': 4.247,
#    'average_cadence': 73.7,
#    'device_watts': False,
#    'average_heartrate': 168.9,
#    'max_heartrate': 187.0,
#    'lap_index': 16,
#    'split': 16,
#    'pace_zone': 1},
#   {'id': 29346036930,
#    'resource_state': 2,
#    'name': 'Lap 17',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 41,
#    'moving_time': 41,
#    'start_date': '2023-03-06T17:31:35Z',
#    'start_date_local': '2023-03-06T18:31:35Z',
#    'distance': 188.9,
#    'start_index': 655,
#    'end_index': 673,
#    'total_elevation_gain': 11.2,
#    'average_speed': 4.61,
#    'max_speed': 5.16,
#    'average_cadence': 88.5,
#    'device_watts': False,
#    'average_heartrate': 176.1,
#    'max_heartrate': 187.0,
#    'lap_index': 17,
#    'split': 17,
#    'pace_zone': 6},
#   {'id': 29346036931,
#    'resource_state': 2,
#    'name': 'Lap 18',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 222,
#    'moving_time': 120,
#    'start_date': '2023-03-06T17:32:17Z',
#    'start_date_local': '2023-03-06T18:32:17Z',
#    'distance': 226.44,
#    'start_index': 674,
#    'end_index': 720,
#    'total_elevation_gain': 0.0,
#    'average_speed': 1.89,
#    'max_speed': 4.186,
#    'average_cadence': 69.7,
#    'device_watts': False,
#    'average_heartrate': 163.3,
#    'max_heartrate': 188.0,
#    'lap_index': 18,
#    'split': 18,
#    'pace_zone': 1},
#   {'id': 29346036932,
#    'resource_state': 2,
#    'name': 'Lap 19',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 22,
#    'moving_time': 22,
#    'start_date': '2023-03-06T17:36:00Z',
#    'start_date_local': '2023-03-06T18:36:00Z',
#    'distance': 101.39,
#    'start_index': 721,
#    'end_index': 737,
#    'total_elevation_gain': 6.2,
#    'average_speed': 4.61,
#    'max_speed': 5.562,
#    'average_cadence': 87.5,
#    'device_watts': False,
#    'average_heartrate': 148.3,
#    'max_heartrate': 167.0,
#    'lap_index': 19,
#    'split': 19,
#    'pace_zone': 6},
#   {'id': 29346036934,
#    'resource_state': 2,
#    'name': 'Lap 20',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 56,
#    'moving_time': 56,
#    'start_date': '2023-03-06T17:36:23Z',
#    'start_date_local': '2023-03-06T18:36:23Z',
#    'distance': 137.25,
#    'start_index': 738,
#    'end_index': 757,
#    'total_elevation_gain': 0.0,
#    'average_speed': 2.45,
#    'max_speed': 4.38,
#    'average_cadence': 72.8,
#    'device_watts': False,
#    'average_heartrate': 163.3,
#    'max_heartrate': 171.0,
#    'lap_index': 20,
#    'split': 20,
#    'pace_zone': 1},
#   {'id': 29346036937,
#    'resource_state': 2,
#    'name': 'Lap 21',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 19,
#    'moving_time': 19,
#    'start_date': '2023-03-06T17:37:20Z',
#    'start_date_local': '2023-03-06T18:37:20Z',
#    'distance': 102.41,
#    'start_index': 758,
#    'end_index': 769,
#    'total_elevation_gain': 5.8,
#    'average_speed': 5.39,
#    'max_speed': 6.162,
#    'average_cadence': 94.7,
#    'device_watts': False,
#    'average_heartrate': 170.1,
#    'max_heartrate': 177.0,
#    'lap_index': 21,
#    'split': 21,
#    'pace_zone': 6},
#   {'id': 29346036940,
#    'resource_state': 2,
#    'name': 'Lap 22',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 59,
#    'moving_time': 59,
#    'start_date': '2023-03-06T17:37:39Z',
#    'start_date_local': '2023-03-06T18:37:39Z',
#    'distance': 128.68,
#    'start_index': 770,
#    'end_index': 793,
#    'total_elevation_gain': 0.0,
#    'average_speed': 2.18,
#    'max_speed': 4.244,
#    'average_cadence': 73.7,
#    'device_watts': False,
#    'average_heartrate': 173.1,
#    'max_heartrate': 180.0,
#    'lap_index': 22,
#    'split': 22,
#    'pace_zone': 1},
#   {'id': 29346036943,
#    'resource_state': 2,
#    'name': 'Lap 23',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 18,
#    'moving_time': 18,
#    'start_date': '2023-03-06T17:38:37Z',
#    'start_date_local': '2023-03-06T18:38:37Z',
#    'distance': 98.51,
#    'start_index': 794,
#    'end_index': 805,
#    'total_elevation_gain': 5.2,
#    'average_speed': 5.47,
#    'max_speed': 6.21,
#    'average_cadence': 96.5,
#    'device_watts': False,
#    'average_heartrate': 175.1,
#    'max_heartrate': 181.0,
#    'lap_index': 23,
#    'split': 23,
#    'pace_zone': 6},
#   {'id': 29346036945,
#    'resource_state': 2,
#    'name': 'Lap 24',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 59,
#    'moving_time': 59,
#    'start_date': '2023-03-06T17:38:55Z',
#    'start_date_local': '2023-03-06T18:38:55Z',
#    'distance': 139.57,
#    'start_index': 806,
#    'end_index': 824,
#    'total_elevation_gain': 0.0,
#    'average_speed': 2.37,
#    'max_speed': 5.515,
#    'average_cadence': 73.3,
#    'device_watts': False,
#    'average_heartrate': 177.5,
#    'max_heartrate': 186.0,
#    'lap_index': 24,
#    'split': 24,
#    'pace_zone': 1},
#   {'id': 29346036948,
#    'resource_state': 2,
#    'name': 'Lap 25',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 19,
#    'moving_time': 19,
#    'start_date': '2023-03-06T17:39:55Z',
#    'start_date_local': '2023-03-06T18:39:55Z',
#    'distance': 105.34,
#    'start_index': 825,
#    'end_index': 833,
#    'total_elevation_gain': 2.8,
#    'average_speed': 5.54,
#    'max_speed': 6.118,
#    'average_cadence': 95.5,
#    'device_watts': False,
#    'average_heartrate': 178.1,
#    'max_heartrate': 184.0,
#    'lap_index': 25,
#    'split': 25,
#    'pace_zone': 6},
#   {'id': 29346036950,
#    'resource_state': 2,
#    'name': 'Lap 26',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 71,
#    'moving_time': 71,
#    'start_date': '2023-03-06T17:40:14Z',
#    'start_date_local': '2023-03-06T18:40:14Z',
#    'distance': 150.21,
#    'start_index': 834,
#    'end_index': 858,
#    'total_elevation_gain': 2.6,
#    'average_speed': 2.12,
#    'max_speed': 5.85,
#    'average_cadence': 71.7,
#    'device_watts': False,
#    'average_heartrate': 172.8,
#    'max_heartrate': 187.0,
#    'lap_index': 26,
#    'split': 26,
#    'pace_zone': 1},
#   {'id': 29346036954,
#    'resource_state': 2,
#    'name': 'Lap 27',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 18,
#    'moving_time': 18,
#    'start_date': '2023-03-06T17:41:26Z',
#    'start_date_local': '2023-03-06T18:41:26Z',
#    'distance': 103.12,
#    'start_index': 859,
#    'end_index': 869,
#    'total_elevation_gain': 4.0,
#    'average_speed': 5.73,
#    'max_speed': 6.344,
#    'average_cadence': 100.2,
#    'device_watts': False,
#    'average_heartrate': 175.5,
#    'max_heartrate': 183.0,
#    'lap_index': 27,
#    'split': 27,
#    'pace_zone': 6},
#   {'id': 29346036957,
#    'resource_state': 2,
#    'name': 'Lap 28',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 67,
#    'moving_time': 67,
#    'start_date': '2023-03-06T17:41:46Z',
#    'start_date_local': '2023-03-06T18:41:46Z',
#    'distance': 141.19,
#    'start_index': 870,
#    'end_index': 894,
#    'total_elevation_gain': 0.0,
#    'average_speed': 2.11,
#    'max_speed': 5.226,
#    'average_cadence': 69.8,
#    'device_watts': False,
#    'average_heartrate': 177.4,
#    'max_heartrate': 187.0,
#    'lap_index': 28,
#    'split': 28,
#    'pace_zone': 1},
#   {'id': 29346036962,
#    'resource_state': 2,
#    'name': 'Lap 29',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 18,
#    'moving_time': 18,
#    'start_date': '2023-03-06T17:42:52Z',
#    'start_date_local': '2023-03-06T18:42:52Z',
#    'distance': 100.39,
#    'start_index': 895,
#    'end_index': 905,
#    'total_elevation_gain': 5.8,
#    'average_speed': 5.58,
#    'max_speed': 7.204,
#    'average_cadence': 99.8,
#    'device_watts': False,
#    'average_heartrate': 175.2,
#    'max_heartrate': 183.0,
#    'lap_index': 29,
#    'split': 29,
#    'pace_zone': 6},
#   {'id': 29346036965,
#    'resource_state': 2,
#    'name': 'Lap 30',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 204,
#    'moving_time': 204,
#    'start_date': '2023-03-06T17:43:11Z',
#    'start_date_local': '2023-03-06T18:43:11Z',
#    'distance': 135.02,
#    'start_index': 906,
#    'end_index': 958,
#    'total_elevation_gain': 0.0,
#    'average_speed': 0.66,
#    'max_speed': 4.976,
#    'average_cadence': 68.8,
#    'device_watts': False,
#    'average_heartrate': 174.5,
#    'max_heartrate': 185.0,
#    'lap_index': 30,
#    'split': 30,
#    'pace_zone': 1},
#   {'id': 29346036972,
#    'resource_state': 2,
#    'name': 'Lap 31',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 461,
#    'moving_time': 461,
#    'start_date': '2023-03-06T17:46:36Z',
#    'start_date_local': '2023-03-06T18:46:36Z',
#    'distance': 1000.0,
#    'start_index': 959,
#    'end_index': 1072,
#    'total_elevation_gain': 47.2,
#    'average_speed': 2.17,
#    'max_speed': 4.468,
#    'average_cadence': 67.1,
#    'device_watts': False,
#    'average_heartrate': 145.8,
#    'max_heartrate': 171.0,
#    'lap_index': 31,
#    'split': 31,
#    'pace_zone': 1},
#   {'id': 29346036978,
#    'resource_state': 2,
#    'name': 'Lap 32',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 104,
#    'moving_time': 104,
#    'start_date': '2023-03-06T17:54:16Z',
#    'start_date_local': '2023-03-06T18:54:16Z',
#    'distance': 133.47,
#    'start_index': 1072,
#    'end_index': 1072,
#    'total_elevation_gain': 2.4,
#    'average_speed': 1.28,
#    'max_speed': 4.206,
#    'average_cadence': 60.7,
#    'device_watts': False,
#    'average_heartrate': 144.9,
#    'max_heartrate': 177.0,
#    'lap_index': 32,
#    'split': 32,
#    'pace_zone': 1},
#   {'id': 29346036982,
#    'resource_state': 2,
#    'name': 'Lap 33',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 72,
#    'moving_time': 72,
#    'start_date': '2023-03-06T17:55:59Z',
#    'start_date_local': '2023-03-06T18:55:59Z',
#    'distance': 70.03,
#    'start_index': 1072,
#    'end_index': 1072,
#    'total_elevation_gain': 2.4,
#    'average_speed': 0.97,
#    'max_speed': 2.412,
#    'average_cadence': 56.7,
#    'device_watts': False,
#    'average_heartrate': 132.2,
#    'max_heartrate': 138.0,
#    'lap_index': 33,
#    'split': 33,
#    'pace_zone': 1}],
#  'best_efforts': [{'id': 24664432351,
#    'resource_state': 2,
#    'name': '400m',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 103,
#    'moving_time': 105,
#    'start_date': '2023-03-06T17:02:13Z',
#    'start_date_local': '2023-03-06T18:02:13Z',
#    'distance': 400,
#    'start_index': 120,
#    'end_index': 150,
#    'pr_rank': None,
#    'achievements': []},
#   {'id': 24664432364,
#    'resource_state': 2,
#    'name': '1/2 mile',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 223,
#    'moving_time': 224,
#    'start_date': '2023-03-06T16:56:10Z',
#    'start_date_local': '2023-03-06T17:56:10Z',
#    'distance': 805,
#    'start_index': 1,
#    'end_index': 73,
#    'pr_rank': None,
#    'achievements': []},
#   {'id': 24664432387,
#    'resource_state': 2,
#    'name': '1k',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 281,
#    'moving_time': 282,
#    'start_date': '2023-03-06T16:56:09Z',
#    'start_date_local': '2023-03-06T17:56:09Z',
#    'distance': 1000,
#    'start_index': 0,
#    'end_index': 95,
#    'pr_rank': None,
#    'achievements': []},
#   {'id': 24664432417,
#    'resource_state': 2,
#    'name': '1 mile',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 453,
#    'moving_time': 454,
#    'start_date': '2023-03-06T16:56:09Z',
#    'start_date_local': '2023-03-06T17:56:09Z',
#    'distance': 1609,
#    'start_index': 0,
#    'end_index': 145,
#    'pr_rank': None,
#    'achievements': []},
#   {'id': 24664432446,
#    'resource_state': 2,
#    'name': '2 mile',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 1283,
#    'moving_time': 976,
#    'start_date': '2023-03-06T16:56:10Z',
#    'start_date_local': '2023-03-06T17:56:10Z',
#    'distance': 3219,
#    'start_index': 1,
#    'end_index': 362,
#    'pr_rank': None,
#    'achievements': []},
#   {'id': 24664432465,
#    'resource_state': 2,
#    'name': '5k',
#    'activity': {'id': 8670834905, 'resource_state': 1},
#    'athlete': {'id': 40990567, 'resource_state': 1},
#    'elapsed_time': 2033,
#    'moving_time': 1628,
#    'start_date': '2023-03-06T16:56:17Z',
#    'start_date_local': '2023-03-06T17:56:17Z',
#    'distance': 5000,
#    'start_index': 3,
#    'end_index': 657,
#    'pr_rank': None,
#    'achievements': []}],
#  'photos': {'primary': None, 'count': 0},
#  'stats_visibility': [{'type': 'heart_rate', 'visibility': 'everyone'},
#   {'type': 'pace', 'visibility': 'everyone'},
#   {'type': 'power', 'visibility': 'everyone'},
#   {'type': 'speed', 'visibility': 'everyone'},
#   {'type': 'calories', 'visibility': 'everyone'}],
#  'hide_from_home': False,
#  'device_name': 'Garmin fēnix 6X',
#  'embed_token': '1fb35c91f2b699d157e8f3c91c45babd9216187c',
#  'similar_activities': {'effort_count': 1,
#   'average_speed': 2.566470831080037,
#   'min_average_speed': 2.566470831080037,
#   'mid_average_speed': 2.566470831080037,
#   'max_average_speed': 2.566470831080037,
#   'pr_rank': None,
#   'frequency_milestone': None,
#   'trend': {'speeds': [2.566470831080037],
#    'current_activity_index': 0,
#    'min_speed': 2.566470831080037,
#    'mid_speed': 2.566470831080037,
#    'max_speed': 2.566470831080037,
#    'direction': 0},
#   'resource_state': 2},
#  'available_zones': ['heartrate', 'pace']}

# %%
activity.keys()
# Out:
# dict_keys(['resource_state', 'athlete', 'name', 'distance', 'moving_time', 'elapsed_time', 'total_elevation_gain', 'type', 'sport_type', 'workout_type', 'id', 'start_date', 'start_date_local', 'timezone', 'utc_offset', 'location_city', 'location_state', 'location_country', 'achievement_count', 'kudos_count', 'comment_count', 'athlete_count', 'photo_count', 'map', 'trainer', 'commute', 'manual', 'private', 'visibility', 'flagged', 'gear_id', 'start_latlng', 'end_latlng', 'average_speed', 'max_speed', 'average_cadence', 'average_temp', 'has_heartrate', 'average_heartrate', 'max_heartrate', 'heartrate_opt_out', 'display_hide_heartrate_option', 'elev_high', 'elev_low', 'upload_id', 'upload_id_str', 'external_id', 'from_accepted_tag', 'pr_count', 'total_photo_count', 'has_kudoed', 'suffer_score', 'description', 'calories', 'perceived_exertion', 'prefer_perceived_exertion', 'segment_efforts', 'splits_metric', 'splits_standard', 'laps', 'best_efforts', 'photos', 'stats_visibility', 'hide_from_home', 'device_name', 'embed_token', 'similar_activities', 'available_zones'])

# %%
laps_df = pd.DataFrame(activity["laps"])

# %%
laps_df
# Out:
#              id  resource_state    name  \
# 0   29346036903               2   Lap 1
# 1   29346036906               2   Lap 2
# 2   29346036909               2   Lap 3
# 3   29346036910               2   Lap 4
# 4   29346036911               2   Lap 5
# 5   29346036914               2   Lap 6
# 6   29346036916               2   Lap 7
# 7   29346036918               2   Lap 8
# 8   29346036920               2   Lap 9
# 9   29346036922               2  Lap 10
# 10  29346036923               2  Lap 11
# 11  29346036924               2  Lap 12
# 12  29346036926               2  Lap 13
# 13  29346036927               2  Lap 14
# 14  29346036928               2  Lap 15
# 15  29346036929               2  Lap 16
# 16  29346036930               2  Lap 17
# 17  29346036931               2  Lap 18
# 18  29346036932               2  Lap 19
# 19  29346036934               2  Lap 20
# 20  29346036937               2  Lap 21
# 21  29346036940               2  Lap 22
# 22  29346036943               2  Lap 23
# 23  29346036945               2  Lap 24
# 24  29346036948               2  Lap 25
# 25  29346036950               2  Lap 26
# 26  29346036954               2  Lap 27
# 27  29346036957               2  Lap 28
# 28  29346036962               2  Lap 29
# 29  29346036965               2  Lap 30
# 30  29346036972               2  Lap 31
# 31  29346036978               2  Lap 32
# 32  29346036982               2  Lap 33
#
#                                    activity  \
# 0   {'id': 8670834905, 'resource_state': 1}
# 1   {'id': 8670834905, 'resource_state': 1}
# 2   {'id': 8670834905, 'resource_state': 1}
# 3   {'id': 8670834905, 'resource_state': 1}
# 4   {'id': 8670834905, 'resource_state': 1}
# 5   {'id': 8670834905, 'resource_state': 1}
# 6   {'id': 8670834905, 'resource_state': 1}
# 7   {'id': 8670834905, 'resource_state': 1}
# 8   {'id': 8670834905, 'resource_state': 1}
# 9   {'id': 8670834905, 'resource_state': 1}
# 10  {'id': 8670834905, 'resource_state': 1}
# 11  {'id': 8670834905, 'resource_state': 1}
# 12  {'id': 8670834905, 'resource_state': 1}
# 13  {'id': 8670834905, 'resource_state': 1}
# 14  {'id': 8670834905, 'resource_state': 1}
# 15  {'id': 8670834905, 'resource_state': 1}
# 16  {'id': 8670834905, 'resource_state': 1}
# 17  {'id': 8670834905, 'resource_state': 1}
# 18  {'id': 8670834905, 'resource_state': 1}
# 19  {'id': 8670834905, 'resource_state': 1}
# 20  {'id': 8670834905, 'resource_state': 1}
# 21  {'id': 8670834905, 'resource_state': 1}
# 22  {'id': 8670834905, 'resource_state': 1}
# 23  {'id': 8670834905, 'resource_state': 1}
# 24  {'id': 8670834905, 'resource_state': 1}
# 25  {'id': 8670834905, 'resource_state': 1}
# 26  {'id': 8670834905, 'resource_state': 1}
# 27  {'id': 8670834905, 'resource_state': 1}
# 28  {'id': 8670834905, 'resource_state': 1}
# 29  {'id': 8670834905, 'resource_state': 1}
# 30  {'id': 8670834905, 'resource_state': 1}
# 31  {'id': 8670834905, 'resource_state': 1}
# 32  {'id': 8670834905, 'resource_state': 1}
#
#                                   athlete  elapsed_time  moving_time  \
# 0   {'id': 40990567, 'resource_state': 1}           281          281
# 1   {'id': 40990567, 'resource_state': 1}           397          219
# 2   {'id': 40990567, 'resource_state': 1}           111          111
# 3   {'id': 40990567, 'resource_state': 1}            28           28
# 4   {'id': 40990567, 'resource_state': 1}           125          125
# 5   {'id': 40990567, 'resource_state': 1}           195          109
# 6   {'id': 40990567, 'resource_state': 1}            28           28
# 7   {'id': 40990567, 'resource_state': 1}           144          141
# 8   {'id': 40990567, 'resource_state': 1}           115          115
# 9   {'id': 40990567, 'resource_state': 1}           306          249
# 10  {'id': 40990567, 'resource_state': 1}            44           44
# 11  {'id': 40990567, 'resource_state': 1}            83           83
# 12  {'id': 40990567, 'resource_state': 1}            42           42
# 13  {'id': 40990567, 'resource_state': 1}            94           94
# 14  {'id': 40990567, 'resource_state': 1}            40           40
# 15  {'id': 40990567, 'resource_state': 1}            82           82
# 16  {'id': 40990567, 'resource_state': 1}            41           41
# 17  {'id': 40990567, 'resource_state': 1}           222          120
# 18  {'id': 40990567, 'resource_state': 1}            22           22
# 19  {'id': 40990567, 'resource_state': 1}            56           56
# 20  {'id': 40990567, 'resource_state': 1}            19           19
# 21  {'id': 40990567, 'resource_state': 1}            59           59
# 22  {'id': 40990567, 'resource_state': 1}            18           18
# 23  {'id': 40990567, 'resource_state': 1}            59           59
# 24  {'id': 40990567, 'resource_state': 1}            19           19
# 25  {'id': 40990567, 'resource_state': 1}            71           71
# 26  {'id': 40990567, 'resource_state': 1}            18           18
# 27  {'id': 40990567, 'resource_state': 1}            67           67
# 28  {'id': 40990567, 'resource_state': 1}            18           18
# 29  {'id': 40990567, 'resource_state': 1}           204          204
# 30  {'id': 40990567, 'resource_state': 1}           461          461
# 31  {'id': 40990567, 'resource_state': 1}           104          104
# 32  {'id': 40990567, 'resource_state': 1}            72           72
#
#               start_date      start_date_local  distance  ...  \
# 0   2023-03-06T16:56:09Z  2023-03-06T17:56:09Z   1000.00  ...
# 1   2023-03-06T17:00:54Z  2023-03-06T18:00:54Z    709.73  ...
# 2   2023-03-06T17:07:30Z  2023-03-06T18:07:30Z    376.11  ...
# 3   2023-03-06T17:09:22Z  2023-03-06T18:09:22Z     15.79  ...
# 4   2023-03-06T17:09:50Z  2023-03-06T18:09:50Z    373.64  ...
# 5   2023-03-06T17:13:22Z  2023-03-06T18:13:22Z    386.65  ...
# 6   2023-03-06T17:15:12Z  2023-03-06T18:15:12Z     32.94  ...
# 7   2023-03-06T17:15:40Z  2023-03-06T18:15:40Z    379.41  ...
# 8   2023-03-06T17:18:05Z  2023-03-06T18:18:05Z    380.76  ...
# 9   2023-03-06T17:20:01Z  2023-03-06T18:20:01Z    353.28  ...
# 10  2023-03-06T17:25:08Z  2023-03-06T18:25:08Z    201.50  ...
# 11  2023-03-06T17:25:53Z  2023-03-06T18:25:53Z    232.28  ...
# 12  2023-03-06T17:27:15Z  2023-03-06T18:27:15Z    183.80  ...
# 13  2023-03-06T17:27:57Z  2023-03-06T18:27:57Z    212.66  ...
# 14  2023-03-06T17:29:32Z  2023-03-06T18:29:32Z    187.09  ...
# 15  2023-03-06T17:30:12Z  2023-03-06T18:30:12Z    214.42  ...
# 16  2023-03-06T17:31:35Z  2023-03-06T18:31:35Z    188.90  ...
# 17  2023-03-06T17:32:17Z  2023-03-06T18:32:17Z    226.44  ...
# 18  2023-03-06T17:36:00Z  2023-03-06T18:36:00Z    101.39  ...
# 19  2023-03-06T17:36:23Z  2023-03-06T18:36:23Z    137.25  ...
# 20  2023-03-06T17:37:20Z  2023-03-06T18:37:20Z    102.41  ...
# 21  2023-03-06T17:37:39Z  2023-03-06T18:37:39Z    128.68  ...
# 22  2023-03-06T17:38:37Z  2023-03-06T18:38:37Z     98.51  ...
# 23  2023-03-06T17:38:55Z  2023-03-06T18:38:55Z    139.57  ...
# 24  2023-03-06T17:39:55Z  2023-03-06T18:39:55Z    105.34  ...
# 25  2023-03-06T17:40:14Z  2023-03-06T18:40:14Z    150.21  ...
# 26  2023-03-06T17:41:26Z  2023-03-06T18:41:26Z    103.12  ...
# 27  2023-03-06T17:41:46Z  2023-03-06T18:41:46Z    141.19  ...
# 28  2023-03-06T17:42:52Z  2023-03-06T18:42:52Z    100.39  ...
# 29  2023-03-06T17:43:11Z  2023-03-06T18:43:11Z    135.02  ...
# 30  2023-03-06T17:46:36Z  2023-03-06T18:46:36Z   1000.00  ...
# 31  2023-03-06T17:54:16Z  2023-03-06T18:54:16Z    133.47  ...
# 32  2023-03-06T17:55:59Z  2023-03-06T18:55:59Z     70.03  ...
#
#     total_elevation_gain  average_speed  max_speed  average_cadence  \
# 0                   15.2           3.56      4.098             82.0
# 1                    9.6           3.24      4.287             79.5
# 2                   23.2           3.39      4.564             76.8
# 3                    0.0           0.56      2.640             45.0
# 4                    0.0           2.99      3.432             76.9
# 5                   21.2           3.55      4.208             79.3
# 6                    0.0           1.18      3.411             50.9
# 7                    0.0           2.69      3.368             75.0
# 8                   19.6           3.31      4.017             77.4
# 9                    0.0           1.42      2.601             53.4
# 10                  13.0           4.58      5.772             87.1
# 11                   2.4           2.80      3.384             75.3
# 12                  11.2           4.38      5.168             85.6
# 13                   0.0           2.26      4.184             73.1
# 14                  10.2           4.68      5.244             90.5
# 15                   0.0           2.61      4.247             73.7
# 16                  11.2           4.61      5.160             88.5
# 17                   0.0           1.89      4.186             69.7
# 18                   6.2           4.61      5.562             87.5
# 19                   0.0           2.45      4.380             72.8
# 20                   5.8           5.39      6.162             94.7
# 21                   0.0           2.18      4.244             73.7
# 22                   5.2           5.47      6.210             96.5
# 23                   0.0           2.37      5.515             73.3
# 24                   2.8           5.54      6.118             95.5
# 25                   2.6           2.12      5.850             71.7
# 26                   4.0           5.73      6.344            100.2
# 27                   0.0           2.11      5.226             69.8
# 28                   5.8           5.58      7.204             99.8
# 29                   0.0           0.66      4.976             68.8
# 30                  47.2           2.17      4.468             67.1
# 31                   2.4           1.28      4.206             60.7
# 32                   2.4           0.97      2.412             56.7
#
#     device_watts  average_heartrate  max_heartrate  lap_index  split  \
# 0          False              139.7          150.0          1      1
# 1          False              156.4          166.0          2      2
# 2          False              162.2          177.0          3      3
# 3          False              174.7          178.0          4      4
# 4          False              131.9          154.0          5      5
# 5          False              161.1          183.0          6      6
# 6          False              176.5          183.0          7      7
# 7          False              134.7          164.0          8      8
# 8          False              169.8          180.0          9      9
# 9          False              113.7          179.0         10     10
# 10         False              156.0          178.0         11     11
# 11         False              166.0          180.0         12     12
# 12         False              174.9          184.0         13     13
# 13         False              165.1          186.0         14     14
# 14         False              172.0          185.0         15     15
# 15         False              168.9          187.0         16     16
# 16         False              176.1          187.0         17     17
# 17         False              163.3          188.0         18     18
# 18         False              148.3          167.0         19     19
# 19         False              163.3          171.0         20     20
# 20         False              170.1          177.0         21     21
# 21         False              173.1          180.0         22     22
# 22         False              175.1          181.0         23     23
# 23         False              177.5          186.0         24     24
# 24         False              178.1          184.0         25     25
# 25         False              172.8          187.0         26     26
# 26         False              175.5          183.0         27     27
# 27         False              177.4          187.0         28     28
# 28         False              175.2          183.0         29     29
# 29         False              174.5          185.0         30     30
# 30         False              145.8          171.0         31     31
# 31         False              144.9          177.0         32     32
# 32         False              132.2          138.0         33     33
#
#     pace_zone
# 0           2
# 1           2
# 2           2
# 3           1
# 4           1
# 5           2
# 6           1
# 7           1
# 8           2
# 9           1
# 10          5
# 11          1
# 12          5
# 13          1
# 14          6
# 15          1
# 16          6
# 17          1
# 18          6
# 19          1
# 20          6
# 21          1
# 22          6
# 23          1
# 24          6
# 25          1
# 26          6
# 27          1
# 28          6
# 29          1
# 30          1
# 31          1
# 32          1
#
# [33 rows x 22 columns]

# %%
def get_activity_zones(
        access_token=tokens["access_token"],
        id=0,
        url = "https://www.strava.com/api/v3/activities/{id}/zones/",
    ):
    header = {"Authorization": f"Bearer {access_token}"}
    payload = {
        "activity": "read",
    }

    # post request
    response = requests.post(
        url=url.format(id=id),
        data=payload,
        headers=header,
    )
    return response.json()

zones_json = get_activity_zones(
    access_token=tokens["access_token"],
    id=ids[idx]
)

zones_json
# Out:
# [{'score': 38.0,
#   'distribution_buckets': [{'min': 0, 'max': 136, 'time': 756},
#    {'min': 136, 'max': 170, 'time': 1377},
#    {'min': 170, 'max': 186, 'time': 749},
#    {'min': 186, 'max': 203, 'time': 14},
#    {'min': 203, 'max': -1, 'time': 0}],
#   'type': 'heartrate',
#   'resource_state': 3,
#   'sensor_based': True,
#   'points': 0,
#   'custom_zones': False},
#  {'score': 3,
#   'distribution_buckets': [{'max': 3.122941981057581, 'min': 0, 'time': 1595},
#    {'max': 3.628123772111013, 'min': 3.122941981057581, 'time': 437},
#    {'max': 4.0414543284274576, 'min': 3.628123772111013, 'time': 328},
#    {'max': 4.31700803263842, 'min': 4.0414543284274576, 'time': 231},
#    {'max': 4.592561736849383, 'min': 4.31700803263842, 'time': 113},
#    {'max': -1, 'min': 4.592561736849383, 'time': 192}],
#   'type': 'pace',
#   'resource_state': 3,
#   'sensor_based': True}]

# %%
ids[idx]
# Out:
# 8670834905

# %%
splits_df = pd.DataFrame(activity['splits_standard'])

# %%
splits_df
# Out:
#    distance  elapsed_time  elevation_difference  moving_time  split  \
# 0    1610.2           454                   2.4          454      1
# 1    1617.1           833                  -7.4          568      2
# 2    1604.2           697                  -0.6          637      3
# 3    1609.5           654                   1.6          552      4
# 4    1608.5           831                  40.8          831      5
# 5     255.6           194                   1.6          194      6
#
#    average_speed  average_grade_adjusted_speed  average_heartrate  pace_zone
# 0           3.55                          3.66         146.169604          3
# 1           2.85                          3.07         148.694981          1
# 2           2.52                          2.72         146.488449          1
# 3           2.92                          3.15         168.874000          2
# 4           1.94                          2.21         155.445967          1
# 5           1.32                          1.49         144.291045          1

# %%
splits_metric_df = pd.DataFrame(activity['splits_metric'])
splits_metric_df
# Out:
#    distance  elapsed_time  elevation_difference  moving_time  split  \
# 0    1001.6           282                   3.8          282      1
# 1     998.5           480                   6.0          302      2
# 2    1001.5           451                  -1.0          364      3
# 3    1000.2           457                 -14.4          454      4
# 4    1007.0           367                   7.8          310      5
# 5     992.1           451                  -3.0          349      6
# 6    1002.5           351                   1.2          351      7
# 7     997.7           606                  33.8          606      8
# 8     304.0           218                   4.2          218      9
#
#    average_speed  average_grade_adjusted_speed  average_heartrate  pace_zone
# 0           3.55                          3.68         139.698582          3
# 1           3.31                          3.55         156.367133          2
# 2           2.75                          3.00         150.193939          1
# 3           2.20                          2.27         133.164733          1
# 4           3.25                          3.63         165.117241          3
# 5           2.84                          3.04         166.305732          1
# 6           2.86                          3.09         175.567073          1
# 7           1.65                          1.89         147.158242          1
# 8           1.39                          1.64         145.986928          1

# %%
streams = """time
distance
latlng
altitude
velocity_smooth
heartrate
cadence
watts
temp
moving
grade_smooth""".split("\n")
streams
# Out:
# ['time',
#  'distance',
#  'latlng',
#  'altitude',
#  'velocity_smooth',
#  'heartrate',
#  'cadence',
#  'watts',
#  'temp',
#  'moving',
#  'grade_smooth']

# %%
def get_activity_stream(
        access_token=tokens["access_token"],
        id=0,
        stream_type="heartrate",  # https://developers.strava.com/docs/reference/#api-models-StreamSet
        url = "https://www.strava.com/api/v3/activities/{id}/streams/",
    ):
    header = {"Authorization": f"Bearer {access_token}"}
    payload = {
        # "activity": "read",
        "keys": stream_type,
        "key_by_type": True

    }

    # get request
    response = requests.get(
        url=url.format(id=id),
        params=payload,
        headers=header,
    )
    return response.json()


def build_stream_df(
        access_token=tokens["access_token"],
        id=0,
        stream_type="heartrate",
): 
    response = get_activity_stream(
        access_token=access_token,
        id=id,
        stream_type=stream_type,
    )

    if "latlng" in response.keys():
        data = {
            "distance": response["distance"]["data"],
            "lat": [x[0] for x in response["latlng"]["data"]],
            "lng": [x[1] for x in response["latlng"]["data"]],
        }
    else:
        data = {
            key: response[key]["data"]
            for key in response.keys() 
        }

    return pd.DataFrame(data)

# %%
def get_streams_df(
    access_token=tokens["access_token"],
    id=ids[idx],
    streams=["cadence", "heartrate", "altitude", "latlng", "velocity_smooth", "grade_smooth"],
):
    df = build_stream_df(
        access_token=access_token,
        id=id,
        stream_type="time",
    )


    for stream in streams:
        tmp_df = build_stream_df(
            access_token=access_token,
            id=id,
            stream_type=stream,
        ).drop(columns="distance")
        df = pd.concat([df, tmp_df], axis=1)
        
    return df.set_index("time")

# %%
streams_df = get_streams_df(streams=["cadence", "heartrate", "altitude", "velocity_smooth"])
streams_df
# Out:
#       distance  cadence  heartrate  altitude  velocity_smooth
# time
# 0          0.0       20        117     126.2            0.000
# 1          3.2       20        117     125.8            0.000
# 7         26.1       88        118     125.2            3.729
# 8         30.0       89        117     125.0            3.829
# 9         33.7       86        117     124.8            3.807
# ...        ...      ...        ...       ...              ...
# 3658    8296.8       58        116     164.8            0.874
# 3659    8298.1       75        117     164.8            1.024
# 3661    8302.0       70        120     164.6            1.316
# 3662    8303.9       69        120     164.6            1.610
# 3663    8305.1       67        119     164.6            1.664
#
# [1214 rows x 5 columns]

# %% [markdown]
# # Plots

# %%
pd.options.plotting.backend = "plotly"

# %%
fig = streams_df.plot()
fig

# %%
figs = []
for col in streams_df.columns:
    fig = streams_df[col].plot()
    fig.show()
    figs.append(fig)
